# %% [markdown]
# ## In this notebook I wll add speakers info to the final dataset for the time being
#
# data_labelled_final.csv

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

from tqdm import tqdm
from ecbdata import ecbdata

# %%
# Import dataset containing the interveiw data
# df = pd.read_csv('data_labelled_final.csv')
df = pd.read_csv('data_labelled_final.csv')

# Convert 'date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

df.tail(20)
# Out:
#      Unnamed: 0       Date                                              Media  \
# 499         499 2023-03-26                       Interview with Business Post
# 500         500 2023-03-05                       Interview with Grupo Vocento
# 501         501 2023-03-01  Interview with IMF Finance and Development mag...
# 502         502 2023-02-28                             Interview with Reuters
# 503         503 2023-02-27          Interview with The Economic Times (India)
# 504         504 2023-02-25                   Interview with Helsingin Sanomat
# 505         505 2023-02-17                           Interview with Bloomberg
# 506         506 2023-02-10                                     Q&A on Twitter
# 507         507 2023-02-08                 Interview with Süddeutsche Zeitung
# 508         508 2023-01-24                        Interview with Handelsblatt
# 509         509 2023-01-17                     Interview with Financial Times
# 510         510 2024-04-23                            Interview with Le Monde
# 511         511 2024-03-19                        Interview with Naftemporiki
# 512         512 2024-02-07                     Interview with Financial Times
# 513         513 2024-02-03                       Interview with De Volkskrant
# 514         514 2024-01-31                            Interview with Die Zeit
# 515         515 2024-01-22                        Thanks to Wolfgang Schäuble
# 516         516 2024-01-13                 Interview with Corriere della Sera
# 517         517 2024-01-10                                           Q&A on X
# 518         518 2024-01-03  Tribute article on Wolfgang Schäuble for Die Zeit
#
#                 Member                                               Link  \
# 499    Luis de Guindos  https://www.ecb.europa.eu/press/inter/date/202...
# 500  Christine Lagarde  https://www.ecb.europa.eu/press/inter/date/202...
# 501     Philip R. Lane  https://www.ecb.europa.eu/press/inter/date/202...
# 502     Philip R. Lane  https://www.ecb.europa.eu/press/inter/date/202...
# 503  Christine Lagarde  https://www.ecb.europa.eu/press/inter/date/202...
# 504  Christine Lagarde  https://www.ecb.europa.eu/press/inter/date/202...
# 505    Isabel Schnabel  https://www.ecb.europa.eu/press/inter/date/202...
# 506    Isabel Schnabel  https://www.ecb.europa.eu/press/inter/date/202...
# 507    Luis de Guindos  https://www.ecb.europa.eu/press/inter/date/202...
# 508      Fabio Panetta  https://www.ecb.europa.eu/press/inter/date/202...
# 509     Philip R. Lane  https://www.ecb.europa.eu/press/inter/date/202...
# 510    Luis de Guindos  https://www.ecb.europa.eu/press/inter/date/202...
# 511    Luis de Guindos  https://www.ecb.europa.eu/press/inter/date/202...
# 512    Isabel Schnabel  https://www.ecb.europa.eu/press/inter/date/202...
# 513     Frank Elderson  https://www.ecb.europa.eu/press/inter/date/202...
# 514    Luis de Guindos  https://www.ecb.europa.eu/press/inter/date/202...
# 515  Christine Lagarde  https://www.ecb.europa.eu/press/inter/date/202...
# 516     Philip R. Lane  https://www.ecb.europa.eu/press/inter/date/202...
# 517    Isabel Schnabel  https://www.ecb.europa.eu/press/inter/date/202...
# 518  Christine Lagarde  https://www.ecb.europa.eu/press/inter/date/202...
#
#                                            Information  \
# 499  Interview with Luis de Guindos, Vice-President...
# 500  Interview with Christine Lagarde, President of...
# 501  Interview with Philip R. Lane, Member of the E...
# 502  Interview with Philip R. Lane, Member of the E...
# 503  Interview with Christine Lagarde, President of...
# 504  Interview with Christine Lagarde, President of...
# 505  Interview with Isabel Schnabel, Member of the ...
# 506  Interview with Isabel Schnabel, Member of the ...
# 507  Interview with Luis de Guindos, Vice-President...
# 508  Interview with Fabio Panetta, Member of the Ex...
# 509  Interview with Philip R. Lane, Member of the E...
# 510  Interview with Luis de Guindos, Vice-President...
# 511  Interview with Luis de Guindos, Vice-President...
# 512  Interview with Isabel Schnabel, Member of the ...
# 513  Interview with Frank Elderson, Member of the E...
# 514  Interview with Luis de Guindos, Vice-President...
# 515  Contribution by Christine Lagarde, President o...
# 516  Interview with Philip R. Lane, Member of the E...
# 517  Interview with Isabel Schnabel, Member of the ...
# 518  Tribute article on Wolfgang Schäuble for Die Z...
#
#                                              Questions  \
# 499  Have you come to expect crisis and are you com...
# 500  Will you raise interest rates by another 50 ba...
# 501  After rising to highs not seen for 40 years, i...
# 502  What is your assessment of economic developmen...
# 503  A generation of central bankers did not bother...
# 504  President Christine Lagarde, the European Comm...
# 505  How much closer are we to achieving 2% inflati...
# 506  Why ECB is not fighting inflation?[end_questio...
# 507  Mr de Guindos, energy prices have fallen recen...
# 508  The guidance the ECB gave in December has been...
# 509  From your perspective, how much do you see the...
# 510  In March, inflation in the euro area was 2.4%,...
# 511  Inflation has been declining and the European ...
# 512  Now that inflation is fading, some say it was ...
# 513  Coming from a supervisor charged with assessin...
# 514  Mr de Guindos, Germany is in a recession, the ...
# 515                                         Disclaimer
# 516  The rate hike in September was meant to increa...
# 517  Who decided that 2% inflation is good and what...
# 518                                                NaN
#
#                                                Answers  \
# 499  26 March 2023[end_answer] The situation is qui...
# 500  5 March 2023[end_answer] It is very likely tha...
# 501  1 March 2023[end_answer] The interview is an u...
# 502  28 February 2023[end_answer] Since the Decembe...
# 503  27 February 2023[end_answer] My predecessors a...
# 504  25 February 2023[end_answer] The most recent p...
# 505  17 February 2023[end_answer] We are still far ...
# 506  10 February 2023[end_answer] Hi all, this is@I...
# 507  8 February 2023[end_answer] No, weshould still...
# 508  24 January 2023[end_answer] Our December proje...
# 509  17 January 2023[end_answer] The way to think a...
# 510  23 April 2024[end_answer] The battle isn’t ove...
# 511  19 March 2024[end_answer] Looking at recent in...
# 512  7 February 2024[end_answer] It's a myth that t...
# 513  3 February 2024[end_answer] In its introductio...
# 514  31 January 2024[end_answer] There are three re...
# 515  Frankfurt am Main, 22 January 2024[end_answer]...
# 516  13 January 2024[end_answer] The first point to...
# 517  10 January 2024[end_answer] Hi all, this is@Is...
# 518  3 January 2024[end_answer] When I think of Wol...
#
#                                              Metaphors  \
# 499  ['optimistic on growth and inflation', 'lower ...
# 500                                                NaN
# 501                                                NaN
# 502                                                NaN
# 503                                                NaN
# 504                                                NaN
# 505                                                NaN
# 506                                                NaN
# 507  ['concerned alow;">low;">bout inflation', 'pre...
# 508                                                NaN
# 509  ['inflationary pressure', 'inflationary enviro...
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
# 516  ['cool down inflation', 'easing of core inflat...
# 517                                                NaN
# 518                                                NaN
#
#                                     Metaphors Sentence
# 499  ['The projections released last week were more...
# 500                                                NaN
# 501                                                NaN
# 502                                                NaN
# 503                                                NaN
# 504                                                NaN
# 505                                                NaN
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509  ['For me the way to differentiate these narrat...
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
# 516  ['By underlining that the ECB will maintain a ...
# 517                                                NaN
# 518                                                NaN

# %%
num_unique_members = df['Member'].nunique()
print(num_unique_members)
# Out:
# 19

# %%
speakers = df['Member'].unique()
speakers_dict = {speaker: '' for speaker in speakers}
# Out:
# ['Jean-Claude Trichet' 'Otmar Issing' 'Lucas Papademos'
#  'Lorenzo Bini Smaghi' 'José Manuel González-Páramo'
#  'Tommaso Padoa-Schioppa' 'Mario Draghi' 'Peter Praet' 'Benoît Cœuré'
#  'Jörg Asmussen' 'Yves Mersch' 'Vítor Constâncio' 'Sabine Lautenschläger'
#  'Christine Lagarde' 'Luis de Guindos' 'Philip R. Lane' 'Isabel Schnabel'
#  'Fabio Panetta' 'Frank Elderson']

# %%
speakers_info = pd.DataFrame(speakers_dict.items(), columns=['Speaker', 'DoB', 'Gender', 'Country'])
