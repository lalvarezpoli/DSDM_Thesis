# %% [markdown]
# ## Descriptive Analysis on ECB Data
# ---------------------

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import aux_functions

# %%
# read csv file
workingdir = os.getcwd()
# read cleaned_data.csv file
#df = pd.read_csv(workingdir + '/ECB_Data.csv')

df = pd.read_csv(workingdir + '/data_complete.csv')

# %%
df
# Out:
#                  Date                                              Media  \
# 0    23 December 2005                         Interview with Der Spiegel
# 1    19 December 2005                  Interview with Hospodářské Noviny
# 2    19 December 2005  Interview with Financial Times and Financial T...
# 3    15 December 2005                         Interview with Paris Match
# 4     9 December 2005                           Interview in Il Giornale
# ..                ...                                                ...
# 514   31 January 2024                            Interview with Die Zeit
# 515   22 January 2024                        Thanks to Wolfgang Schäuble
# 516   13 January 2024                 Interview with Corriere della Sera
# 517   10 January 2024                                           Q&A on X
# 518    3 January 2024  Tribute article on Wolfgang Schäuble for Die Zeit
#
#                   Member                                               Link  \
# 0    Jean-Claude Trichet  https://www.ecb.europa.eu/press/inter/date/200...
# 1           Otmar Issing  https://www.ecb.europa.eu/press/inter/date/200...
# 2        Lucas Papademos  https://www.ecb.europa.eu/press/inter/date/200...
# 3    Jean-Claude Trichet  https://www.ecb.europa.eu/press/inter/date/200...
# 4    Lorenzo Bini Smaghi  https://www.ecb.europa.eu/press/inter/date/200...
# ..                   ...                                                ...
# 514      Luis de Guindos  https://www.ecb.europa.eu/press/inter/date/202...
# 515    Christine Lagarde  https://www.ecb.europa.eu/press/inter/date/202...
# 516       Philip R. Lane  https://www.ecb.europa.eu/press/inter/date/202...
# 517      Isabel Schnabel  https://www.ecb.europa.eu/press/inter/date/202...
# 518    Christine Lagarde  https://www.ecb.europa.eu/press/inter/date/202...
#
#                                            Information  \
# 0                                Information not found
# 1                                Information not found
# 2                                Information not found
# 3                                Information not found
# 4                                Information not found
# ..                                                 ...
# 514  Interview with Luis de Guindos, Vice-President...
# 515  Contribution by Christine Lagarde, President o...
# 516  Interview with Philip R. Lane, Member of the E...
# 517  Interview with Isabel Schnabel, Member of the ...
# 518  Tribute article on Wolfgang Schäuble for Die Z...
#
#                                              Questions  \
# 0    SPIEGEL: Monsieur Trichet, any concrete uttera...
# 1    The new EU member states want to adopt the eur...
# 2    Mr Papademos, you have responsibility as ECB V...
# 3    Paris Match. After two uneventful years at the...
# 4    However, Europe’s politicians, with few except...
# ..                                                 ...
# 514  Mr de Guindos, Germany is in a recession, the ...
# 515                                         Disclaimer
# 516  The rate hike in September was meant to increa...
# 517  Who decided that 2% inflation is good and what...
# 518                                                NaN
#
#                                                Answers
# 0    The publication of the translation was authori...
# 1    These questions are all closely related to eac...
# 2    A comparison of the risks involved when short-...
# 3    The publication of the translation was authori...
# 4    By Angelo Allegri, our correspondent in Frankf...
# ..                                                 ...
# 514  31 January 2024[end_answer] There are three re...
# 515  Frankfurt am Main, 22 January 2024[end_answer]...
# 516  13 January 2024[end_answer] The first point to...
# 517  10 January 2024[end_answer] Hi all, this is@Is...
# 518  3 January 2024[end_answer] When I think of Wol...
#
# [519 rows x 7 columns]

# %% [markdown]
# Remove every Na

# %%
# removing Nas
df = df.dropna()

# %% [markdown]
# Converting the data into desired type (everything columns are encoded as objects)

# %%
#types of data
df.dtypes
# Out:
# Date           object
# Media          object
# Member         object
# Link           object
# Information    object
# Questions      object
# Answers        object
# dtype: object

# %%
import pandas as pd

# Load your data - assuming it's loaded into DataFrame 'df'
# df = pd.read_csv('your_file.csv')  # Uncomment this if you're reading from a CSV file

# rename Date column to date
df.rename(columns={'Date': 'date'}, inplace=True)

# rename Answers column to content
df.rename(columns={'Answers': 'contents'}, inplace=True)

# Convert 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'])

# Convert all other columns to string type, except 'date'
for col in df.columns:
    if col != 'date':
        df[col] = df[col].astype(str)

# Verify the data types
print(df.dtypes)
# Out:
# date           datetime64[ns]
# Media                  object
# Member                 object
# Link                   object
# Information            object
# Questions              object
# contents               object
# dtype: object
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3664216846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Date': 'date'}, inplace=True)
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3664216846.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Answers': 'contents'}, inplace=True)
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3664216846.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3664216846.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str)
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3664216846.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str)
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3664216846.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str)
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3664216846.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str)
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3664216846.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str)
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3664216846.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str)

# %% [markdown]
# ## Descriptive Analysis

# %%
# describe the data
df.describe()
# Out:
#                                 date
# count                            459
# mean   2017-09-27 02:24:18.823529472
# min              2005-01-20 00:00:00
# 25%              2015-02-02 12:00:00
# 50%              2019-02-19 00:00:00
# 75%              2021-04-10 00:00:00
# max              2024-04-23 00:00:00

# %%
#ECB Color
color = (17/255, 49/255, 147/255)

# %% [markdown]
# 1. Word Frequency Analysis

# %%
from collections import Counter
import pandas as pd
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure that NLTK stopwords are downloaded
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def word_frequency(df):
    # Join all texts in the 'contents' column
    all_text = ' '.join(df['contents'].tolist()).lower()
    words = all_text.split()
    # Filter out stopwords
    filtered_words = [word for word in words if word not in stop_words and word.isalpha()]
    frequency = Counter(filtered_words)
    return frequency.most_common()

# Apply the function
word_freq = word_frequency(df)

# If the result looks correct, proceed to plot
if word_freq:
    # Plots the 20 most frequent words
    plt.figure(figsize=(12, 6), dpi=300)
    df_plot = pd.DataFrame(word_freq, columns=['Word', 'Frequency']).head(20)
    sns.barplot(x='Frequency', y='Word', data=df_plot, color=color)
    plt.title('20 Most Frequent Words Excluding Stopwords')
    plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mathieu26/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# 2. Sentiment Analysis

# %%
from textblob import TextBlob

def sentiment_analysis(df):
    df['sentiment'] = df['contents'].apply(lambda x: TextBlob(x).sentiment.polarity)
    return df

# Apply the function
df = sentiment_analysis(df)
# Out:
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/3035613002.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment'] = df['contents'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
# Plot the sentiment over time
plt.figure(figsize=(10, 5), dpi = 300)
df.sort_values('date').set_index('date')['sentiment'].plot(kind='line', color=color)
plt.title('Sentiment Score Over Time')
plt.xlabel('Date')
plt.ylabel('Sentiment Score')
plt.grid(True)
plt.show()

# %% [markdown]
# The sentiment score calculated from the TextBlob library reflects the emotional tone of the content within the contents column of your DataFrame, which includes transcripts of interviews from the ECB on inflation. Here's how to interpret the sentiment score:
#
# Polarity: This is a float within the range [-1.0, 1.0] where -1.0 denotes extreme negativity, 0 denotes neutrality, and 1.0 denotes extreme positivity. The sentiment.polarity attribute returns this polarity score for each text.

# %% [markdown]
# 2.1. Part-of-speech tagging using TextBlob

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/mathieu26/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import pandas as pd
from textblob import TextBlob

# Assuming 'df' is your DataFrame and it has a column 'contents' with transcripts

def pos_tagging(text):
    # Create a TextBlob object
    blob = TextBlob(text)
    # Return part of speech tags
    return blob.tags

# Apply the POS tagging function to each row in the 'contents' column
df['pos_tags'] = df['contents'].apply(pos_tagging)
# Out:
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/2442230502.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pos_tags'] = df['contents'].apply(pos_tagging)

# %%
df.head
# Out:
# <bound method NDFrame.head of           date                                              Media  \
# 0   2005-12-23                         Interview with Der Spiegel
# 1   2005-12-19                  Interview with Hospodářské Noviny
# 2   2005-12-19  Interview with Financial Times and Financial T...
# 3   2005-12-15                         Interview with Paris Match
# 4   2005-12-09                           Interview in Il Giornale
# ..         ...                                                ...
# 513 2024-02-03                       Interview with De Volkskrant
# 514 2024-01-31                            Interview with Die Zeit
# 515 2024-01-22                        Thanks to Wolfgang Schäuble
# 516 2024-01-13                 Interview with Corriere della Sera
# 517 2024-01-10                                           Q&A on X
#
#                   Member                                               Link  \
# 0    Jean-Claude Trichet  https://www.ecb.europa.eu/press/inter/date/200...
# 1           Otmar Issing  https://www.ecb.europa.eu/press/inter/date/200...
# 2        Lucas Papademos  https://www.ecb.europa.eu/press/inter/date/200...
# 3    Jean-Claude Trichet  https://www.ecb.europa.eu/press/inter/date/200...
# 4    Lorenzo Bini Smaghi  https://www.ecb.europa.eu/press/inter/date/200...
# ..                   ...                                                ...
# 513       Frank Elderson  https://www.ecb.europa.eu/press/inter/date/202...
# 514      Luis de Guindos  https://www.ecb.europa.eu/press/inter/date/202...
# 515    Christine Lagarde  https://www.ecb.europa.eu/press/inter/date/202...
# 516       Philip R. Lane  https://www.ecb.europa.eu/press/inter/date/202...
# 517      Isabel Schnabel  https://www.ecb.europa.eu/press/inter/date/202...
#
#                                            Information  \
# 0                                Information not found
# 1                                Information not found
# 2                                Information not found
# 3                                Information not found
# 4                                Information not found
# ..                                                 ...
# 513  Interview with Frank Elderson, Member of the E...
# 514  Interview with Luis de Guindos, Vice-President...
# 515  Contribution by Christine Lagarde, President o...
# 516  Interview with Philip R. Lane, Member of the E...
# 517  Interview with Isabel Schnabel, Member of the ...
#
#                                              Questions  \
# 0    SPIEGEL: Monsieur Trichet, any concrete uttera...
# 1    The new EU member states want to adopt the eur...
# 2    Mr Papademos, you have responsibility as ECB V...
# 3    Paris Match. After two uneventful years at the...
# 4    However, Europe’s politicians, with few except...
# ..                                                 ...
# 513  Coming from a supervisor charged with assessin...
# 514  Mr de Guindos, Germany is in a recession, the ...
# 515                                         Disclaimer
# 516  The rate hike in September was meant to increa...
# 517  Who decided that 2% inflation is good and what...
#
#                                               contents  sentiment  \
# 0    The publication of the translation was authori...   0.137979
# 1    These questions are all closely related to eac...   0.173579
# 2    A comparison of the risks involved when short-...   0.084569
# 3    The publication of the translation was authori...   0.152205
# 4    By Angelo Allegri, our correspondent in Frankf...   0.094762
# ..                                                 ...        ...
# 513  3 February 2024[end_answer] In its introductio...   0.083336
# 514  31 January 2024[end_answer] There are three re...   0.066284
# 515  Frankfurt am Main, 22 January 2024[end_answer]...   0.178342
# 516  13 January 2024[end_answer] The first point to...   0.180326
# 517  10 January 2024[end_answer] Hi all, this is@Is...   0.093776
#
#                                               pos_tags
# 0    [(The, DT), (publication, NN), (of, IN), (the,...
# 1    [(These, DT), (questions, NNS), (are, VBP), (a...
# 2    [(A, DT), (comparison, NN), (of, IN), (the, DT...
# 3    [(The, DT), (publication, NN), (of, IN), (the,...
# 4    [(By, IN), (Angelo, NNP), (Allegri, NNP), (our...
# ..                                                 ...
# 513  [(3, CD), (February, NNP), (2024, CD), ([, NNP...
# 514  [(31, CD), (January, NNP), (2024, CD), ([, NNP...
# 515  [(Frankfurt, NNP), (am, VBP), (Main, NNP), (22...
# 516  [(13, CD), (January, NNP), (2024, CD), ([, NNP...
# 517  [(10, CD), (January, NNP), (2024, CD), ([, NNP...
#
# [459 rows x 9 columns]>

# %% [markdown]
# Using function stored in py file to display contents of the variables

# %%
aux_functions.print_contents(df,20, "pos_tags")
# Out:
# Content 1: [('The', 'DT'), ('publication', 'NN'), ('of', 'IN'), ('the', 'DT'), ('translation', 'NN'), ('was', 'VBD'), ('authorised', 'VBN'), ('by', 'IN'), ('Der', 'NNP'), ('Spiegel', 'NNP'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Trichet', 'NNP'), ('laughs', 'VBZ'), ('Of', 'IN'), ('course', 'NN'), ('the', 'DT'), ('“', 'JJ'), ('porte-parole', 'JJ'), ('”', 'NN'), ('of', 'IN'), ('the', 'DT'), ('ECB', 'NNP'), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('all', 'DT'), ('members', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('decision-making', 'JJ'), ('bodies', 'NNS'), ('must', 'MD'), ('be', 'VB'), ('aware', 'JJ'), ('that', 'IN'), ('their', 'PRP$'), ('statements', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('hugely', 'RB'), ('significant', 'JJ'), ('for', 'IN'), ('large', 'JJ'), ('numbers', 'NNS'), ('of', 'IN'), ('people', 'NNS'), ('The', 'DT'), ('euro', 'JJ'), ('area', 'NN'), ('has', 'VBZ'), ('311', 'CD'), ('million', 'CD'), ('citizens', 'NNS'), ('after', 'IN'), ('all', 'DT'), ('And', 'CC'), ('when', 'WRB'), ('I', 'PRP'), ('say', 'VBP'), ('something', 'NN'), ('in', 'IN'), ('the', 'DT'), ('SPIEGEL', 'NNP'), ('I', 'PRP'), ('’', 'VBP'), ('m', 'JJ'), ('virtually', 'RB'), ('speaking', 'VBG'), ('to', 'TO'), ('more', 'JJR'), ('than', 'IN'), ('80', 'CD'), ('million', 'CD'), ('Germans', 'NNPS'), ('But', 'CC'), ('that', 'DT'), ('sort', 'NN'), ('of', 'IN'), ('thing', 'NN'), ('imposes', 'VBZ'), ('a', 'DT'), ('heavy', 'JJ'), ('responsibility', 'NN'), ('not', 'RB'), ('only', 'RB'), ('on', 'IN'), ('us', 'PRP'), ('but', 'CC'), ('also', 'RB'), ('on', 'IN'), ('all', 'PDT'), ('those', 'DT'), ('persons', 'NNS'), ('who', 'WP'), ('have', 'VBP'), ('important', 'JJ'), ('responsibilities…', 'NN'), ('[', 'NNP'), ('end_answer', 'VBZ'), (']', 'VB'), ('It', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('contrary', 'JJ'), ('We', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('give', 'VB'), ('clear', 'JJ'), ('positions', 'NNS'), ('and', 'CC'), ('clear', 'JJ'), ('answers', 'NNS'), ('not', 'RB'), ('only', 'RB'), ('to', 'TO'), ('311', 'CD'), ('million', 'CD'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('but', 'CC'), ('to', 'TO'), ('the', 'DT'), ('European', 'NNP'), ('and', 'CC'), ('global', 'JJ'), ('investors', 'NNS'), ('and', 'CC'), ('savers', 'NNS'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('As', 'IN'), ('regards', 'NNS'), ('future', 'JJ'), ('monetary', 'JJ'), ('policy', 'NN'), ('I', 'PRP'), ('reiterate', 'VBP'), ('what', 'WP'), ('I', 'PRP'), ('said', 'VBD'), ('on', 'IN'), ('behalf', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Governing', 'NNP'), ('Council', 'NNP'), ('following', 'VBG'), ('our', 'PRP$'), ('most', 'RBS'), ('recent', 'JJ'), ('decision', 'NN'), ('“', 'NN'), ('We', 'PRP'), ('did', 'VBD'), ('not', 'RB'), ('decide', 'VB'), ('“', 'NNP'), ('ex', 'FW'), ('ante', 'NN'), ('”', 'NN'), ('to', 'TO'), ('engage', 'VB'), ('in', 'IN'), ('a', 'DT'), ('series', 'NN'), ('of', 'IN'), ('interest', 'NN'), ('rate', 'NN'), ('increases', 'NNS'), ('We', 'PRP'), ('will', 'MD'), ('in', 'IN'), ('the', 'DT'), ('future', 'JJ'), ('take', 'VB'), ('the', 'DT'), ('decisions', 'NNS'), ('that', 'WDT'), ('will', 'MD'), ('be', 'VB'), ('necessary', 'JJ'), ('to', 'TO'), ('deliver', 'VB'), ('price', 'NN'), ('stability', 'NN'), ('to', 'TO'), ('be', 'VB'), ('credible', 'JJ'), ('in', 'IN'), ('delivering', 'VBG'), ('price', 'NN'), ('stability', 'NN'), ('over', 'IN'), ('time', 'NN'), ('and', 'CC'), ('to', 'TO'), ('preserve', 'VB'), ('the', 'DT'), ('solid', 'JJ'), ('anchoring', 'NN'), ('of', 'IN'), ('inflationary', 'JJ'), ('expectations', 'NNS'), ('at', 'IN'), ('levels', 'NNS'), ('consistent', 'JJ'), ('with', 'IN'), ('price', 'NN'), ('stability', 'NN'), ('”', 'NNP'), ('This', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('Governing', 'VBG'), ('Council', 'NNP'), ('’', 'NNP'), ('s', 'POS'), ('position', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Again', 'NNP'), ('It', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('position', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Governing', 'NNP'), ('Council', 'NNP'), ('I', 'PR ...
# Content 2: [('These', 'DT'), ('questions', 'NNS'), ('are', 'VBP'), ('all', 'DT'), ('closely', 'RB'), ('related', 'VBN'), ('to', 'TO'), ('each', 'DT'), ('other', 'JJ'), ('and', 'CC'), ('the', 'DT'), ('answer', 'NN'), ('is', 'VBZ'), ('always', 'RB'), ('the', 'DT'), ('same', 'JJ'), ('a', 'DT'), ('country', 'NN'), ('should', 'MD'), ('not', 'RB'), ('rush', 'VB'), ('but', 'CC'), ('be', 'VB'), ('well', 'RB'), ('prepared', 'JJ'), ('before', 'IN'), ('giving', 'VBG'), ('up', 'RP'), ('its', 'PRP$'), ('monetary', 'JJ'), ('policy', 'NN'), ('and', 'CC'), ('the', 'DT'), ('option', 'NN'), ('of', 'IN'), ('changes', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('exchange', 'NN'), ('rate', 'NN'), ('by', 'IN'), ('joining', 'VBG'), ('the', 'DT'), ('euro', 'NN'), ('In', 'IN'), ('any', 'DT'), ('case', 'NN'), ('the', 'DT'), ('country', 'NN'), ('must', 'MD'), ('fulfil', 'VB'), ('the', 'DT'), ('convergence', 'NN'), ('criteria', 'NNS'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Flexible', 'NNP'), ('markets', 'NNS'), ('in', 'IN'), ('general', 'JJ'), ('and', 'CC'), ('flexible', 'JJ'), ('labour', 'NN'), ('markets', 'NNS'), ('in', 'IN'), ('particular', 'JJ'), ('are', 'VBP'), ('conducive', 'JJ'), ('to', 'TO'), ('economic', 'JJ'), ('growth', 'NN'), ('and', 'CC'), ('job', 'NN'), ('creation', 'NN'), ('in', 'IN'), ('each', 'DT'), ('country', 'NN'), ('Flexible', 'JJ'), ('markets', 'NNS'), ('are', 'VBP'), ('a', 'DT'), ('fundamental', 'JJ'), ('precondition', 'NN'), ('for', 'IN'), ('a', 'DT'), ('successful', 'JJ'), ('monetary', 'JJ'), ('union', 'NN'), ('In', 'IN'), ('this', 'DT'), ('respect', 'NN'), ('we', 'PRP'), ('have', 'VBP'), ('seen', 'VBN'), ('much', 'JJ'), ('progress', 'NN'), ('over', 'IN'), ('the', 'DT'), ('last', 'JJ'), ('years', 'NNS'), ('–', 'VBD'), ('different', 'JJ'), ('from', 'IN'), ('country', 'NN'), ('to', 'TO'), ('country', 'NN'), ('Yet', 'RB'), ('a', 'DT'), ('lot', 'NN'), ('has', 'VBZ'), ('to', 'TO'), ('be', 'VB'), ('done', 'VBN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Access', 'NNP'), ('to', 'TO'), ('EU', 'NNP'), ('was', 'VBD'), ('a', 'DT'), ('desire', 'NN'), ('for', 'IN'), ('many', 'JJ'), ('years', 'NNS'), ('for', 'IN'), ('these', 'DT'), ('ten', 'JJ'), ('countries', 'NNS'), ('In', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('place', 'NN'), ('membership', 'NN'), ('means', 'VBZ'), ('living', 'VBG'), ('together', 'RB'), ('in', 'IN'), ('peace', 'NN'), ('under', 'IN'), ('a', 'DT'), ('common', 'JJ'), ('roof', 'NN'), ('Participation', 'NN'), ('in', 'IN'), ('the', 'DT'), ('EU', 'NNP'), ('which', 'WDT'), ('is', 'VBZ'), ('still', 'RB'), ('very', 'RB'), ('recent', 'JJ'), ('will', 'MD'), ('bring', 'VB'), ('great', 'JJ'), ('economic', 'JJ'), ('advantages', 'NNS'), ('–', 'VBP'), ('a', 'DT'), ('single', 'JJ'), ('market', 'NN'), ('of', 'IN'), ('almost', 'RB'), ('460', 'CD'), ('million', 'CD'), ('people', 'NNS'), ('offers', 'VBZ'), ('great', 'JJ'), ('chances', 'NNS'), ('The', 'DT'), ('rules', 'NNS'), ('have', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('same', 'JJ'), ('for', 'IN'), ('every', 'DT'), ('single', 'JJ'), ('country', 'NN'), ('–', 'NN'), ('for', 'IN'), ('large', 'JJ'), ('and', 'CC'), ('small', 'JJ'), ('countries', 'NNS'), ('for', 'IN'), ('old', 'JJ'), ('and', 'CC'), ('new', 'JJ'), ('members', 'NNS'), ('I', 'PRP'), ('personally', 'RB'), ('do', 'VBP'), ('not', 'RB'), ('see', 'VB'), ('any', 'DT'), ('need', 'NN'), ('for', 'IN'), ('tax', 'NN'), ('harmonisation', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Within', 'IN'), ('the', 'DT'), ('euro', 'JJ'), ('area', 'NN'), ('we', 'PRP'), ('also', 'RB'), ('have', 'VBP'), ('some', 'DT'), ('countries', 'NNS'), ('that', 'WDT'), ('exhibit', 'VBP'), ('higher', 'JJR'), ('growth', 'NN'), ('rates', 'NNS'), ('than', 'IN'), ('others', 'NNS'), ('However', 'RB'), ('our', 'PRP$'), ('studies', 'NNS'), ('show', 'VBP'), ('that', 'IN'), ('differences', 'NNS'), ('in', 'IN'), ('growth', 'NN'), ('rates', 'NNS'), ('between', 'IN'), ('euro', 'JJ'), ('area', 'NN'), ('countries', 'NNS'), ('are', 'VBP'), ('m ...
# Content 3: [('A', 'DT'), ('comparison', 'NN'), ('of', 'IN'), ('the', 'DT'), ('risks', 'NNS'), ('involved', 'VBN'), ('when', 'WRB'), ('short-term', 'JJ'), ('rates', 'NNS'), ('are', 'VBP'), ('rising', 'VBG'), ('with', 'IN'), ('the', 'DT'), ('risks', 'NNS'), ('to', 'TO'), ('financial', 'JJ'), ('stability', 'NN'), ('of', 'IN'), ('rates', 'NNS'), ('remaining', 'VBG'), ('low', 'JJ'), ('is', 'VBZ'), ('not', 'RB'), ('easy', 'JJ'), ('as', 'IN'), ('it', 'PRP'), ('depends', 'VBZ'), ('on', 'IN'), ('the', 'DT'), ('relative', 'JJ'), ('assessment', 'NN'), ('of', 'IN'), ('the', 'DT'), ('two', 'CD'), ('types', 'NNS'), ('of', 'IN'), ('risks', 'NNS'), ('and', 'CC'), ('on', 'IN'), ('the', 'DT'), ('magnitude', 'NN'), ('of', 'IN'), ('a', 'DT'), ('potential', 'JJ'), ('increase', 'NN'), ('in', 'IN'), ('short-term', 'JJ'), ('rates', 'NNS'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NN'), ('On', 'IN'), ('the', 'DT'), ('whole', 'NN'), ('I', 'PRP'), ('would', 'MD'), ('expect', 'VB'), ('that', 'IN'), ('potential', 'JJ'), ('increases', 'NNS'), ('in', 'IN'), ('global', 'JJ'), ('interest', 'NN'), ('rates', 'NNS'), ('–', 'VBP'), ('not', 'RB'), ('necessarily', 'RB'), ('in', 'IN'), ('the', 'DT'), ('euro', 'JJ'), ('area', 'NN'), ('–', 'NN'), ('that', 'WDT'), ('are', 'VBP'), ('moderate', 'JJ'), ('and', 'CC'), ('anticipated', 'JJ'), ('should', 'MD'), ('not', 'RB'), ('involve', 'VB'), ('risks', 'NNS'), ('to', 'TO'), ('financial', 'JJ'), ('stability', 'NN'), ('Needless', 'NN'), ('to', 'TO'), ('add', 'VB'), ('the', 'DT'), ('size', 'NN'), ('of', 'IN'), ('possible', 'JJ'), ('risks', 'NNS'), ('will', 'MD'), ('differ', 'VB'), ('across', 'IN'), ('countries', 'NNS'), ('and', 'CC'), ('sectors', 'NNS'), ('Let', 'VB'), ('me', 'PRP'), ('elaborate', 'VB'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NN'), ('When', 'WRB'), ('interest', 'NN'), ('rates', 'NNS'), ('remain', 'VBP'), ('at', 'IN'), ('a', 'DT'), ('low', 'JJ'), ('level', 'NN'), ('for', 'IN'), ('a', 'DT'), ('long', 'JJ'), ('period', 'NN'), ('of', 'IN'), ('time', 'NN'), ('they', 'PRP'), ('may', 'MD'), ('entail', 'VB'), ('risks', 'NNS'), ('to', 'TO'), ('financial', 'JJ'), ('stability', 'NN'), ('as', 'IN'), ('a', 'DT'), ('result', 'NN'), ('of', 'IN'), ('their', 'PRP$'), ('effects', 'NNS'), ('on', 'IN'), ('households', 'NNS'), ('corporations', 'NNS'), ('and', 'CC'), ('financial', 'JJ'), ('institutions', 'NNS'), ('For', 'IN'), ('example', 'NN'), ('low', 'JJ'), ('interest', 'NN'), ('rates', 'NNS'), ('have', 'VBP'), ('contributed', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('rapid', 'JJ'), ('rise', 'NN'), ('in', 'IN'), ('household', 'NN'), ('debt', 'NN'), ('and', 'CC'), ('the', 'DT'), ('fast', 'JJ'), ('increase', 'NN'), ('in', 'IN'), ('house', 'NN'), ('prices', 'NNS'), ('in', 'IN'), ('many', 'JJ'), ('countries', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('euro', 'JJ'), ('area', 'NN'), ('but', 'CC'), ('also', 'RB'), ('elsewhere', 'RB'), ('The', 'DT'), ('sustainability', 'NN'), ('of', 'IN'), ('household', 'NN'), ('indebtedness', 'NN'), ('and', 'CC'), ('related', 'VBN'), ('credit', 'NN'), ('risks', 'NNS'), ('when', 'WRB'), ('interest', 'NN'), ('rates', 'NNS'), ('rise', 'VBP'), ('depend', 'VB'), ('on', 'IN'), ('the', 'DT'), ('ability', 'NN'), ('of', 'IN'), ('households', 'NNS'), ('to', 'TO'), ('service', 'VB'), ('their', 'PRP$'), ('debts', 'NNS'), ('and', 'CC'), ('on', 'IN'), ('their', 'PRP$'), ('buffers', 'NNS'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NN'), ('In', 'IN'), ('the', 'DT'), ('euro', 'JJ'), ('area', 'NN'), ('despite', 'IN'), ('increased', 'JJ'), ('indebtedness', 'NN'), ('households', 'NNS'), ('have', 'VBP'), ('comfortable', 'JJ'), ('buffers', 'NNS'), ('Debt-to-asset', 'JJ'), ('ratios', 'NNS'), ('are', 'VBP'), ('sufficiently', 'RB'), ('low', 'JJ'), ('in', 'IN'), ('the', 'DT'), ('euro', 'JJ'), ('area', 'NN'), ('as', 'IN'), ('a', 'DT'), ('whole', 'NN'), ('and', 'CC'), ('the', 'DT'), ('ability', 'NN'), ('of', 'IN'), ('households', 'NNS'), ('to', 'TO'), ('service', 'VB'), ('their', 'PRP$'), ('debt', 'NN'), ('is', 'VBZ'), ('not', 'RB' ...
# Content 4: [('The', 'DT'), ('publication', 'NN'), ('of', 'IN'), ('the', 'DT'), ('translation', 'NN'), ('was', 'VBD'), ('authorised', 'VBN'), ('by', 'IN'), ('Paris', 'NNP'), ('Match', 'NNP'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Jean-Claude', 'NNP'), ('Trichet', 'NNP'), ('I', 'PRP'), ('would', 'MD'), ('not', 'RB'), ('say', 'VB'), ('that', 'IN'), ('the', 'DT'), ('last', 'JJ'), ('two', 'CD'), ('years', 'NNS'), ('have', 'VBP'), ('been', 'VBN'), ('uneventful', 'JJ'), ('It', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('necessary', 'JJ'), ('to', 'TO'), ('safeguard', 'VB'), ('price', 'NN'), ('stability', 'NN'), ('in', 'IN'), ('a', 'DT'), ('period', 'NN'), ('made', 'VBN'), ('very', 'RB'), ('difficult', 'JJ'), ('by', 'IN'), ('the', 'DT'), ('increase', 'NN'), ('in', 'IN'), ('oil', 'NN'), ('prices', 'NNS'), ('Moreover', 'RB'), ('it', 'PRP'), ('is', 'VBZ'), ('only', 'RB'), ('to', 'TO'), ('be', 'VB'), ('expected', 'VBN'), ('in', 'IN'), ('large', 'JJ'), ('and', 'CC'), ('exemplary', 'JJ'), ('democracies', 'NNS'), ('that', 'WDT'), ('different', 'JJ'), ('opinions', 'NNS'), ('should', 'MD'), ('be', 'VB'), ('voiced', 'VBN'), ('It', 'PRP'), ('is', 'VBZ'), ('up', 'IN'), ('to', 'TO'), ('us', 'PRP'), ('to', 'TO'), ('speak', 'VB'), ('out', 'RP'), ('tirelessly', 'RB'), ('and', 'CC'), ('marshal', 'VB'), ('the', 'DT'), ('most', 'RBS'), ('convincing', 'JJ'), ('arguments', 'NNS'), ('That', 'DT'), ('said', 'VBD'), ('I', 'PRP'), ('believe', 'VBP'), ('that', 'IN'), ('the', 'DT'), ('public', 'JJ'), ('debate', 'NN'), ('did', 'VBD'), ('not', 'RB'), ('reflect', 'VB'), ('the', 'DT'), ('true', 'JJ'), ('feelings', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('311', 'CD'), ('million', 'CD'), ('European', 'JJ'), ('and', 'CC'), ('60', 'CD'), ('million', 'CD'), ('French', 'JJ'), ('citizens', 'NNS'), ('All', 'PDT'), ('the', 'DT'), ('indications', 'NNS'), ('are', 'VBP'), ('that', 'IN'), ('that', 'DT'), ('our', 'PRP$'), ('fellow', 'JJ'), ('European', 'JJ'), ('citizens', 'NNS'), ('require', 'VBP'), ('us', 'PRP'), ('to', 'TO'), ('be', 'VB'), ('vigilant', 'JJ'), ('with', 'IN'), ('regard', 'NN'), ('to', 'TO'), ('price', 'NN'), ('stability', 'NN'), ('and', 'CC'), ('that', 'IN'), ('they', 'PRP'), ('are', 'VBP'), ('not', 'RB'), ('overly', 'RB'), ('content', 'JJ'), ('with', 'IN'), ('the', 'DT'), ('situation', 'NN'), ('as', 'IN'), ('it', 'PRP'), ('stands', 'VBZ'), ('I', 'PRP'), ('would', 'MD'), ('have', 'VB'), ('preferred', 'VBN'), ('at', 'IN'), ('least', 'JJS'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('public', 'JJ'), ('debate', 'NN'), ('in', 'IN'), ('Europe', 'NNP'), ('and', 'CC'), ('France', 'NNP'), ('to', 'TO'), ('have', 'VB'), ('focused', 'VBN'), ('on', 'IN'), ('what', 'WP'), ('our', 'PRP$'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('want', 'VBP'), ('We', 'PRP'), ('believe', 'VBP'), ('that', 'IN'), ('by', 'IN'), ('remaining', 'VBG'), ('faithful', 'NN'), ('to', 'TO'), ('our', 'PRP$'), ('mandate', 'NN'), ('–', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('to', 'TO'), ('safeguard', 'VB'), ('price', 'NN'), ('stability', 'NN'), ('and', 'CC'), ('preserve', 'VB'), ('the', 'DT'), ('euro', 'NN'), ('’', 'NNP'), ('s', 'VBD'), ('purchasing', 'VBG'), ('power', 'NN'), ('–', 'IN'), ('we', 'PRP'), ('are', 'VBP'), ('doing', 'VBG'), ('what', 'WP'), ('311', 'CD'), ('million', 'CD'), ('Europeans', 'NNPS'), ('require', 'NN'), ('of', 'IN'), ('us', 'PRP'), ('while', 'IN'), ('at', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('time', 'NN'), ('by', 'IN'), ('doing', 'VBG'), ('so', 'IN'), ('we', 'PRP'), ('are', 'VBP'), ('supporting', 'VBG'), ('growth', 'NN'), ('and', 'CC'), ('job', 'NN'), ('creation', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('J.-C.', 'NNP'), ('T.', 'NNP'), ('You', 'PRP'), ('are', 'VBP'), ('exaggerating', 'VBG'), ('the', 'DT'), ('increase', 'NN'), ('in', 'IN'), ('the', 'DT'), ('cost', 'NN'), ('of', 'IN'), ('a', 'DT'), ('loaf', 'NN'), ('or', 'CC'), ('an', 'DT'), ('espresso', 'NN'), ('on', 'IN'), ('1', 'CD'), ('January', 'NNP'), ('2002', 'CD'), ('In', 'IN'), ('some', 'DT'),  ...
# Content 5: [('By', 'IN'), ('Angelo', 'NNP'), ('Allegri', 'NNP'), ('our', 'PRP$'), ('correspondent', 'NN'), ('in', 'IN'), ('Frankfurt', 'NNP'), ('[', 'NNP'), ('end_answer', 'NN'), (']', 'NNP'), ('“', 'VBZ'), ('The', 'DT'), ('very', 'RB'), ('low', 'JJ'), ('interest', 'NN'), ('rates', 'NNS'), ('that', 'IN'), ('we', 'PRP'), ('have', 'VBP'), ('seen', 'VBN'), ('for', 'IN'), ('the', 'DT'), ('past', 'JJ'), ('two', 'CD'), ('and', 'CC'), ('a', 'DT'), ('half', 'JJ'), ('years', 'NNS'), ('were', 'VBD'), ('not', 'RB'), ('only', 'RB'), ('no', 'RB'), ('longer', 'RBR'), ('sustainable', 'JJ'), ('but', 'CC'), ('could', 'MD'), ('also', 'RB'), ('have', 'VB'), ('become', 'VBN'), ('harmful', 'JJ'), ('We', 'PRP'), ('therefore', 'RB'), ('decided', 'VBD'), ('to', 'TO'), ('raise', 'VB'), ('them', 'PRP'), ('And', 'CC'), ('the', 'DT'), ('markets', 'NNS'), ('have', 'VBP'), ('demonstrated', 'VBN'), ('by', 'IN'), ('their', 'PRP$'), ('reaction', 'NN'), ('that', 'IN'), ('they', 'PRP'), ('have', 'VBP'), ('understood', 'VBN'), ('our', 'PRP$'), ('move', 'NN'), ('”', 'NN'), ('So', 'RB'), ('said', 'VBD'), ('Lorenzo', 'NNP'), ('Bini', 'NNP'), ('Smaghi', 'NNP'), ('speaking', 'NN'), ('in', 'IN'), ('his', 'PRP$'), ('office', 'NN'), ('on', 'IN'), ('the', 'DT'), ('34th', 'JJ'), ('floor', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Eurotower', 'NNP'), ('in', 'IN'), ('Frankfurt', 'NNP'), ('commenting', 'VBG'), ('on', 'IN'), ('the', 'DT'), ('recent', 'JJ'), ('shift', 'NN'), ('by', 'IN'), ('the', 'DT'), ('European', 'JJ'), ('Central', 'NNP'), ('Bank', 'NNP'), ('ECB', 'NNP'), ('which', 'WDT'), ('after', 'IN'), ('five', 'CD'), ('years', 'NNS'), ('of', 'IN'), ('cuts', 'NNS'), ('has', 'VBZ'), ('raised', 'VBN'), ('the', 'DT'), ('cost', 'NN'), ('of', 'IN'), ('money', 'NN'), ('from', 'IN'), ('2', 'CD'), ('%', 'NN'), ('to', 'TO'), ('2.25', 'CD'), ('%', 'NN'), ('This', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('first', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('’', 'NNP'), ('s', 'NNP'), ('president', 'NN'), ('Jean‑Claude', 'NNP'), ('Trichet', 'NNP'), ('who', 'WP'), ('became', 'VBD'), ('head', 'NN'), ('of', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('in', 'IN'), ('November', 'NNP'), ('2003', 'CD'), ('rates', 'NNS'), ('had', 'VBD'), ('remained', 'VBN'), ('unchanged', 'JJ'), ('since', 'IN'), ('June', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('year', 'NN'), ('It', 'PRP'), ('’', 'VBZ'), ('s', 'NN'), ('also', 'RB'), ('a', 'DT'), ('first', 'JJ'), ('for', 'IN'), ('Bini', 'NNP'), ('Smaghi', 'NNP'), ('who', 'WP'), ('joined', 'VBD'), ('the', 'DT'), ('Executive', 'NNP'), ('Board', 'NNP'), ('–', 'VBD'), ('the', 'DT'), ('six-member', 'JJ'), ('body', 'NN'), ('that', 'IN'), ('steers', 'NNS'), ('European', 'JJ'), ('monetary', 'JJ'), ('policy', 'NN'), ('[', 'NNP'), ('sic', 'JJ'), (']', 'NNP'), ('–', 'NNP'), ('last', 'JJ'), ('June', 'NNP'), ('“', 'IN'), ('The', 'DT'), ('rise', 'NN'), ('has', 'VBZ'), ('helped', 'VBN'), ('to', 'TO'), ('keep', 'VB'), ('inflation', 'NN'), ('expectations', 'NNS'), ('low', 'JJ'), ('with', 'IN'), ('positive', 'JJ'), ('effects', 'NNS'), ('on', 'IN'), ('long-term', 'JJ'), ('rates', 'NNS'), ('which', 'WDT'), ('have', 'VBP'), ('stayed', 'VBN'), ('at', 'IN'), ('very', 'RB'), ('low', 'JJ'), ('levels', 'NNS'), ('”', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('“', 'NNP'), ('Tremonti', 'NNP'), ('gave', 'VBD'), ('a', 'DT'), ('balanced', 'JJ'), ('opinion', 'NN'), ('These', 'DT'), ('decisions', 'NNS'), ('should', 'MD'), ('not', 'RB'), ('be', 'VB'), ('exciting', 'JJ'), ('particularly', 'RB'), ('for', 'IN'), ('the', 'DT'), ('markets', 'NNS'), ('Tremonti', 'NNP'), ('is', 'VBZ'), ('well', 'RB'), ('aware', 'JJ'), ('that', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('largely', 'RB'), ('thanks', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('ECB', 'NNP'), ('and', 'CC'), ('its', 'PRP$'), ('credibility', 'NN'), ('that', 'IN'), ('the', 'DT'), ('Italian', 'JJ'), ('Treasury', 'NNP'), ('can', 'MD'), ('borrow', 'VB'), ('at', 'IN'), ('a', 'DT'), ('ten-year', 'JJ'), ('rate', 'NN'), ('of', 'IN'), ...
# Content 6: [('The', 'DT'), ('publication', 'NN'), ('of', 'IN'), ('the', 'DT'), ('text', 'NN'), ('was', 'VBD'), ('authorised', 'VBN'), ('by', 'IN'), ('Die', 'NNP'), ('Welt', 'NNP'), ('La', 'NNP'), ('Stampa', 'NNP'), ('and', 'CC'), ('Libération', 'NNP'), ('The', 'DT'), ('interview', 'NN'), ('has', 'VBZ'), ('not', 'RB'), ('been', 'VBN'), ('published', 'VBN'), ('in', 'IN'), ('full', 'JJ'), ('length', 'NN'), ('in', 'IN'), ('all', 'DT'), ('three', 'CD'), ('newspapers', 'NNS'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'VBD'), ('A', 'DT'), ('At', 'IN'), ('the', 'DT'), ('last', 'JJ'), ('press', 'NN'), ('conference', 'NN'), ('I', 'PRP'), ('had', 'VBD'), ('stressed', 'VBN'), ('that', 'IN'), ('we', 'PRP'), ('could', 'MD'), ('increase', 'VB'), ('rates', 'NNS'), ('at', 'IN'), ('any', 'DT'), ('time', 'NN'), ('as', 'IN'), ('the', 'DT'), ('risks', 'NNS'), ('had', 'VBD'), ('increased', 'VBN'), ('And', 'CC'), ('all', 'PDT'), ('the', 'DT'), ('observers', 'NNS'), ('noted', 'VBD'), ('that', 'IN'), ('our', 'PRP$'), ('vigilant', 'JJ'), ('stance', 'NN'), ('had', 'VBD'), ('strengthened', 'VBN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'VBD'), ('A', 'DT'), ('The', 'DT'), ('Governing', 'VBG'), ('Council', 'NNP'), ('is', 'VBZ'), ('not', 'RB'), ('alarmist', 'JJ'), ('It', 'PRP'), ('is', 'VBZ'), ('vigilant', 'JJ'), ('It', 'PRP'), ('is', 'VBZ'), ('faithful', 'JJ'), ('to', 'TO'), ('its', 'PRP$'), ('mandate', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('to', 'TO'), ('guarantee', 'VB'), ('price', 'NN'), ('stability', 'NN'), ('It', 'PRP'), ('knows', 'VBZ'), ('that', 'IN'), ('this', 'DT'), ('is', 'VBZ'), ('what', 'WP'), ('is', 'VBZ'), ('required', 'VBN'), ('of', 'IN'), ('it', 'PRP'), ('by', 'IN'), ('311', 'CD'), ('million', 'CD'), ('European', 'JJ'), ('citizens', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('euro', 'JJ'), ('area', 'NN'), ('who', 'WP'), ('strongly', 'RB'), ('call', 'VBP'), ('for', 'IN'), ('price', 'NN'), ('stability', 'NN'), ('It', 'PRP'), ('knows', 'VBZ'), ('that', 'IN'), ('this', 'DT'), ('is', 'VBZ'), ('what', 'WP'), ('is', 'VBZ'), ('expected', 'VBN'), ('of', 'IN'), ('it', 'PRP'), ('by', 'IN'), ('European', 'JJ'), ('and', 'CC'), ('global', 'JJ'), ('investors', 'NNS'), ('and', 'CC'), ('savers', 'NNS'), ('who', 'WP'), ('place', 'VBP'), ('their', 'PRP$'), ('trust', 'NN'), ('in', 'IN'), ('the', 'DT'), ('ECB', 'NNP'), ('The', 'DT'), ('risks', 'NNS'), ('of', 'IN'), ('a', 'DT'), ('price', 'NN'), ('rise', 'NN'), ('in', 'IN'), ('the', 'DT'), ('medium', 'NN'), ('term', 'NN'), ('have', 'VBP'), ('increased', 'VBN'), ('These', 'DT'), ('risks', 'NNS'), ('must', 'MD'), ('be', 'VB'), ('prevented', 'VBN'), ('from', 'IN'), ('materialising', 'VBG'), ('Prevention', 'NN'), ('is', 'VBZ'), ('always', 'RB'), ('better', 'JJR'), ('than', 'IN'), ('cure', 'NN'), ('in', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('interest', 'NN'), ('of', 'IN'), ('growth', 'NN'), ('and', 'CC'), ('job', 'NN'), ('creation', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'VBD'), ('A', 'DT'), ('The', 'DT'), ('ECB', 'NNP'), ('has', 'VBZ'), ('always', 'RB'), ('been', 'VBN'), ('very', 'RB'), ('predictable', 'JJ'), ('in', 'IN'), ('its', 'PRP$'), ('interest', 'NN'), ('rate', 'NN'), ('decisions', 'NNS'), ('Academic', 'NNP'), ('research', 'NN'), ('has', 'VBZ'), ('generally', 'RB'), ('found', 'VBN'), ('the', 'DT'), ('ECB', 'NNP'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('most', 'RBS'), ('predictable', 'JJ'), ('together', 'RB'), ('with', 'IN'), ('the', 'DT'), ('US', 'NNP'), ('Federal', 'NNP'), ('Reserve', 'NNP'), ('System', 'NNP'), ('I', 'PRP'), ('have', 'VBP'), ('conveyed', 'VBN'), ('the', 'DT'), ('sentiment', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Governing', 'NNP'), ('Council', 'NNP'), ('at', 'IN'), ('a', 'DT'), ('time', 'NN'), ('when', 'WRB'), ('doing', 'VBG'), ('so', 'RB'), ('was', 'VBD'), ('useful', 'JJ'), ('for', 'IN'), ('everyone', 'NN'), ('for', 'IN'), ('public', 'JJ'), ('opinion', 'NN'), ('for', 'IN'), ('our', 'PRP$'), ('institutional', 'JJ'), ('partners', 'NNS'), ('who', 'WP'), ('made', 'VBD'), ('a', ' ...
# Content 7: [('When', 'WRB'), ('the', 'DT'), ('rouble', 'JJ'), ('becomes', 'NNS'), ('convertible', 'JJ'), ('will', 'MD'), ('Russia', 'NNP'), ('go', 'VB'), ('across', 'IN'), ('to', 'TO'), ('the', 'DT'), ('euro', 'NN'), ('and', 'CC'), ('what', 'WDT'), ('will', 'MD'), ('the', 'DT'), ('new', 'JJ'), ('European', 'JJ'), ('banknotes', 'NNS'), ('be', 'VB'), ('like', 'IN'), ('These', 'DT'), ('questions', 'NNS'), ('were', 'VBD'), ('put', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('President', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('European', 'JJ'), ('Central', 'NNP'), ('Bank', 'NNP'), ('Jean-Claude', 'NNP'), ('Trichet', 'NNP'), ('in', 'IN'), ('an', 'DT'), ('exclusive', 'JJ'), ('interview', 'NN'), ('with', 'IN'), ('“', 'NNP'), ('Izvestia', 'NNP'), ('”', 'NNP'), ('correspondent', 'NN'), ('Igor', 'NNP'), ('Moiseev', 'NNP'), ('Mr', 'NNP'), ('Trichet', 'NNP'), ('arrived', 'VBD'), ('in', 'IN'), ('Sanktt', 'NNP'), ('Petersburg', 'NNP'), ('yesterday', 'NN'), ('to', 'TO'), ('hold', 'VB'), ('a', 'DT'), ('seminar', 'NN'), ('on', 'IN'), ('monetary', 'JJ'), ('and', 'CC'), ('credit', 'NN'), ('policy', 'NN'), ('with', 'IN'), ('his', 'PRP$'), ('Russian', 'JJ'), ('colleague', 'NN'), ('Sergey', 'NNP'), ('Ignatiev', 'NNP'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('For', 'IN'), ('many', 'JJ'), ('years', 'NNS'), ('now', 'RB'), ('the', 'DT'), ('ECB', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('Bank', 'NNP'), ('of', 'IN'), ('Russia', 'NNP'), ('have', 'VBP'), ('developed', 'VBN'), ('strong', 'JJ'), ('bilateral', 'JJ'), ('ties', 'NNS'), ('to', 'TO'), ('which', 'WDT'), ('I', 'PRP'), ('attach', 'VBP'), ('a', 'DT'), ('great', 'JJ'), ('significance', 'NN'), ('As', 'IN'), ('central', 'JJ'), ('bankers', 'NNS'), ('we', 'PRP'), ('have', 'VBP'), ('established', 'VBN'), ('a', 'DT'), ('regular', 'JJ'), ('dialogue', 'NN'), ('with', 'IN'), ('the', 'DT'), ('Bank', 'NNP'), ('of', 'IN'), ('Russia', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('seminar', 'NN'), ('in', 'IN'), ('Sankt', 'NNP'), ('Petersburg', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('most', 'RBS'), ('visible', 'JJ'), ('part', 'NN'), ('of', 'IN'), ('this', 'DT'), ('exchange', 'NN'), ('of', 'IN'), ('views', 'NNS'), ('on', 'IN'), ('a', 'DT'), ('wide', 'JJ'), ('range', 'NN'), ('of', 'IN'), ('issues', 'NNS'), ('In', 'IN'), ('addition', 'NN'), ('over', 'IN'), ('the', 'DT'), ('past', 'JJ'), ('two', 'CD'), ('years', 'NNS'), ('the', 'DT'), ('ECB', 'NNP'), ('together', 'RB'), ('with', 'IN'), ('nine', 'CD'), ('euro', 'JJ'), ('area', 'NN'), ('national', 'JJ'), ('central', 'JJ'), ('banks', 'NNS'), ('and', 'CC'), ('three', 'CD'), ('EU', 'NNP'), ('supervisory', 'JJ'), ('authorities', 'NNS'), ('has', 'VBZ'), ('with', 'IN'), ('EU', 'NNP'), ('funding', 'NN'), ('implemented', 'VBD'), ('an', 'DT'), ('unprecedented', 'JJ'), ('training', 'NN'), ('programme', 'NN'), ('in', 'IN'), ('the', 'DT'), ('area', 'NN'), ('of', 'IN'), ('banking', 'NN'), ('supervision', 'NN'), ('for', 'IN'), ('Bank', 'NNP'), ('of', 'IN'), ('Russia', 'NNP'), ('staff', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Convertibility', 'NNP'), ('of', 'IN'), ('currencies', 'NNS'), ('is', 'VBZ'), ('the', 'DT'), ('normal', 'JJ'), ('situation', 'NN'), ('in', 'IN'), ('a', 'DT'), ('market', 'NN'), ('economy', 'NN'), ('Our', 'PRP$'), ('position', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('markets', 'NNS'), ('should', 'MD'), ('decide', 'VB'), ('on', 'IN'), ('the', 'DT'), ('exchange', 'NN'), ('rates', 'NNS'), ('that', 'IN'), ('ensure', 'VB'), ('equilibrium', 'NN'), ('and', 'CC'), ('reflect', 'VB'), ('all', 'DT'), ('elements', 'NNS'), ('of', 'IN'), ('each', 'DT'), ('country', 'NN'), ('or', 'CC'), ('groups', 'NNS'), ('of', 'IN'), ('countries', 'NNS'), ('prospects', 'NNS'), ('developments', 'NNS'), ('political', 'JJ'), ('and', 'CC'), ('economic', 'JJ'), ('stability', 'NN'), ('I', 'PRP'), ('do', 'VBP'), ('not', 'RB'), ('take', 'VB'), ('any', 'DT'), ('position', 'NN'), ('on', 'IN'), ('internal', 'JJ'), ('developments', 'NNS'), ('within', 'IN'), ('Russia', 'NNP'), ('[', 'NN'), ('end_a ...
# Content 8: [('The', 'DT'), ('publication', 'NN'), ('of', 'IN'), ('the', 'DT'), ('text', 'NN'), ('was', 'VBD'), ('authorised', 'VBN'), ('by', 'IN'), ('The', 'DT'), ('Irish', 'NNP'), ('Times', 'NNP'), ('Le', 'NNP'), ('Figaro', 'NNP'), ('El', 'NNP'), ('Mundo', 'NNP'), ('and', 'CC'), ('Frankfurter', 'NNP'), ('Allgemeine', 'NNP'), ('Zeitung', 'NNP'), ('The', 'DT'), ('interview', 'NN'), ('has', 'VBZ'), ('not', 'RB'), ('been', 'VBN'), ('published', 'VBN'), ('in', 'IN'), ('full', 'JJ'), ('length', 'NN'), ('in', 'IN'), ('all', 'PDT'), ('these', 'DT'), ('newspapers', 'NNS'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'IN'), ('It', 'PRP'), ('is', 'VBZ'), ('true', 'JJ'), ('we', 'PRP'), ('have', 'VBP'), ('an', 'DT'), ('oil', 'NN'), ('shock', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('very', 'RB'), ('significant', 'JJ'), ('But', 'CC'), ('it', 'PRP'), ('is', 'VBZ'), ('different', 'JJ'), ('from', 'IN'), ('previous', 'JJ'), ('shocks', 'NNS'), ('This', 'DT'), ('one', 'CD'), ('is', 'VBZ'), ('not', 'RB'), ('primarily', 'RB'), ('driven', 'VBN'), ('by', 'IN'), ('supply', 'NN'), ('restraints', 'NNS'), ('but', 'CC'), ('by', 'IN'), ('buoyant', 'JJ'), ('world', 'NN'), ('demand', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('changing', 'VBG'), ('relative', 'JJ'), ('prices', 'NNS'), ('for', 'IN'), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), ('other', 'JJ'), ('commodities', 'NNS'), ('as', 'IN'), ('well', 'RB'), ('So', 'IN'), ('we', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('careful', 'JJ'), ('in', 'IN'), ('analysing', 'VBG'), ('the', 'DT'), ('effect', 'NN'), ('of', 'IN'), ('this', 'DT'), ('shock', 'NN'), ('It', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('job', 'NN'), ('of', 'IN'), ('the', 'DT'), ('ECB', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('Governing', 'VBG'), ('Council', 'NNP'), ('to', 'TO'), ('be', 'VB'), ('as', 'RB'), ('credible', 'JJ'), ('as', 'IN'), ('possible', 'JJ'), ('and', 'CC'), ('therefore', 'RB'), ('to', 'TO'), ('solidly', 'RB'), ('anchor', 'VB'), ('inflationary', 'JJ'), ('expectations', 'NNS'), ('It', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('damaging', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('European', 'NNP'), ('and', 'CC'), ('world', 'NN'), ('economy', 'NN'), ('if', 'IN'), ('oil', 'NN'), ('price', 'NN'), ('spikes', 'NNS'), ('would', 'MD'), ('become', 'VB'), ('enshrined', 'VBN'), ('in', 'IN'), ('inflationary', 'JJ'), ('expectations', 'NNS'), ('and', 'CC'), ('thus', 'RB'), ('lead', 'VB'), ('to', 'TO'), ('higher', 'JJR'), ('permanent', 'JJ'), ('inflation', 'NN'), ('We', 'PRP'), ('are', 'VBP'), ('therefore', 'RB'), ('being', 'VBG'), ('particularly', 'RB'), ('vigilant', 'NN'), ('in', 'IN'), ('order', 'NN'), ('to', 'TO'), ('avoid', 'VB'), ('such', 'JJ'), ('destabilising', 'JJ'), ('second', 'JJ'), ('round', 'NN'), ('effects', 'NNS'), ('that', 'WDT'), ('might', 'MD'), ('damage', 'VB'), ('growth', 'NN'), ('and', 'CC'), ('job', 'NN'), ('creation', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('said', 'VBD'), ('clearly', 'RB'), ('to', 'TO'), ('markets', 'NNS'), ('observers', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('people', 'NNS'), ('of', 'IN'), ('Europe', 'NNP'), ('why', 'WRB'), ('avoiding', 'VBG'), ('second', 'JJ'), ('round', 'NN'), ('effects', 'NNS'), ('is', 'VBZ'), ('important', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('European', 'JJ'), ('economy', 'NN'), ('Until', 'IN'), ('now', 'RB'), ('this', 'DT'), ('is', 'VBZ'), ('well', 'RB'), ('understood', 'JJ'), ('by', 'IN'), ('observers', 'NNS'), ('and', 'CC'), ('social', 'JJ'), ('partners', 'NNS'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'IN'), ('The', 'DT'), ('G7', 'NNP'), ('needs', 'VBZ'), ('to', 'TO'), ('discuss', 'VB'), ('what', 'WP'), ('has', 'VBZ'), ('happened', 'VBN'), ('on', 'IN'), ('oil', 'NN'), ('and', 'CC'), ('how', 'WRB'), ('to', 'TO'), ('deal', 'VB'), ('with', 'IN'), ('it', 'PRP'), ('collectively', 'RB'), ('Oil', 'NN'), ('remains', 'VBZ'), ('a', 'DT'), ('major', 'JJ'), ('risk', 'NN'), ('just', 'RB'), ('like', 'IN'), ('global', 'JJ'), ('imbalances', 'NNS'), ('There', 'EX'), ('is', 'VBZ'), ('a', 'DT') ...
# Content 9: [('Is', 'VBZ'), ('the', 'DT'), ('economic', 'JJ'), ('slowdown', 'NN'), ('in', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('part', 'NN'), ('of', 'IN'), ('this', 'DT'), ('year', 'NN'), ('which', 'WDT'), ('has', 'VBZ'), ('caused', 'VBN'), ('so', 'RB'), ('many', 'JJ'), ('observers', 'NNS'), ('to', 'TO'), ('fear', 'VB'), ('the', 'DT'), ('worst', 'JJS'), ('over', 'RB'), ('at', 'IN'), ('last', 'JJ'), ('The', 'DT'), ('latest', 'JJS'), ('indications', 'NNS'), ('coming', 'VBG'), ('from', 'IN'), ('the', 'DT'), ('European', 'JJ'), ('economy', 'NN'), ('are', 'VBP'), ('positive', 'JJ'), ('The', 'DT'), ('short-term', 'JJ'), ('indicators', 'NNS'), ('in', 'IN'), ('many', 'JJ'), ('countries', 'NNS'), ('have', 'VBP'), ('risen', 'VBN'), ('businesses', 'NNS'), ("'", 'POS'), ('confidence', 'NN'), ('in', 'IN'), ('the', 'DT'), ('euro', 'JJ'), ('area', 'NN'), ('has', 'VBZ'), ('improved', 'VBN'), ('and', 'CC'), ('there', 'EX'), ('has', 'VBZ'), ('been', 'VBN'), ('a', 'DT'), ('rise', 'NN'), ('in', 'IN'), ('exports', 'NNS'), ('and', 'CC'), ('orders', 'NNS'), ('for', 'IN'), ('industry', 'NN'), ('Internal', 'JJ'), ('demand', 'NN'), ('is', 'VBZ'), ('still', 'RB'), ('weak', 'JJ'), ('though', 'RB'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'IN'), ('The', 'DT'), ('ECB', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('Governing', 'VBG'), ('Council', 'NNP'), ('opted', 'VBD'), ('to', 'TO'), ('leave', 'VB'), ('interest', 'NN'), ('rates', 'NNS'), ('unchanged', 'JJ'), ('at', 'IN'), ('its', 'PRP$'), ('summer', 'NN'), ('meeting', 'NN'), ('last', 'JJ'), ('Thursday', 'NNP'), ('In', 'IN'), ('the', 'DT'), ('absence', 'NN'), ('of', 'IN'), ('President', 'NNP'), ('Jean-Claude', 'NNP'), ('Trichet', 'NNP'), ("'s", 'POS'), ('customary', 'JJ'), ('monthly', 'JJ'), ('press', 'NN'), ('conference', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('never', 'RB'), ('held', 'VBN'), ('in', 'IN'), ('August', 'NNP'), ('Il', 'NNP'), ('Sole-24', 'NNP'), ('Oreasked', 'NNP'), ('Otmar', 'NNP'), ('Issing', 'NNP'), ('the', 'DT'), ('chief', 'JJ'), ('economist', 'NN'), ('and', 'CC'), ('a', 'DT'), ('member', 'NN'), ('of', 'IN'), ('the', 'DT'), ('ECB', 'NNP'), ("'s", 'POS'), ('Executive', 'NNP'), ('Board', 'NNP'), ('for', 'IN'), ('an', 'DT'), ('update', 'NN'), ('of', 'IN'), ('the', 'DT'), ('economic', 'JJ'), ('situation', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NN'), ('In', 'IN'), ('this', 'DT'), ('interview', 'NN'), ('Issing', 'VBG'), ('continues', 'VBZ'), ('to', 'TO'), ('voice', 'VB'), ('caution', 'NN'), ('He', 'PRP'), ('confirms', 'VBZ'), ('a', 'DT'), ('scenario', 'NN'), ('of', 'IN'), ('gradual', 'JJ'), ('economic', 'JJ'), ('recovery', 'NN'), ('but', 'CC'), ('he', 'PRP'), ('places', 'VBZ'), ('the', 'DT'), ('stress', 'NN'), ('on', 'IN'), ('the', 'DT'), ('danger', 'NN'), ('that', 'IN'), ('the', 'DT'), ('high', 'JJ'), ('price', 'NN'), ('of', 'IN'), ('oil', 'NN'), ('represents', 'VBZ'), ('for', 'IN'), ('growth', 'NN'), ('Right', 'RB'), ('now', 'RB'), ('the', 'DT'), ('central', 'JJ'), ('banker', 'NN'), ('feels', 'NNS'), ('that', 'IN'), ('Europe', 'NNP'), ("'s", 'POS'), ('economy', 'NN'), ('is', 'VBZ'), ('growing', 'VBG'), ('below', 'IN'), ('its', 'PRP$'), ('potential', 'JJ'), ('which', 'WDT'), ('many', 'JJ'), ('international', 'JJ'), ('institutions', 'NNS'), ('have', 'VBP'), ('estimated', 'VBN'), ('at', 'IN'), ('1.9', 'CD'), ('%', 'NN'), ('for', 'IN'), ('the', 'DT'), ('two-year', 'JJ'), ('period', 'NN'), ('from', 'IN'), ('2005', 'CD'), ('to', 'TO'), ('2006', 'CD'), ('he', 'PRP'), ('declined', 'VBD'), ('to', 'TO'), ('make', 'VB'), ('any', 'DT'), ('forecasts', 'NNS'), ('as', 'IN'), ('to', 'TO'), ('when', 'WRB'), ('it', 'PRP'), ('might', 'MD'), ('return', 'VB'), ('to', 'TO'), ('this', 'DT'), ('level', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NN'), ('In', 'IN'), ('the', 'DT'), ('course', 'NN'), ('of', 'IN'), ('our', 'PRP$'), ('chat', 'NN'), ('Issing', 'VBG'), ('chose', 'NN'), ('to', 'TO'), ('focus', 'VB'), ('on', 'IN'), ('the', 'DT'), ('economic', 'JJ'), ('situation', 'NN'), ('in', 'IN'), ('Europe',  ...
# Content 10: [('English', 'JJ'), ('translation', 'NN'), ('of', 'IN'), ('an', 'DT'), ('interview', 'NN'), ('published', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('edition', 'NN'), ('of', 'IN'), ('La', 'NNP'), ('Gaceta', 'NNP'), ('de', 'IN'), ('los', 'FW'), ('Negocios', 'NNP'), ('dated', 'VBD'), ('27', 'CD'), ('June', 'NNP'), ('2005', 'CD'), ('The', 'DT'), ('publication', 'NN'), ('of', 'IN'), ('the', 'DT'), ('translation', 'NN'), ('was', 'VBD'), ('authorised', 'VBN'), ('by', 'IN'), ('La', 'NNP'), ('Gaceta', 'NNP'), ('de', 'IN'), ('los', 'FW'), ('Negocios', 'NNP'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'JJ'), ('Interest', 'NNP'), ('rates', 'NNS'), ('today', 'NN'), ('are', 'VBP'), ('appropriate', 'JJ'), ('but', 'CC'), ('the', 'DT'), ('ECB', 'NNP'), ('will', 'MD'), ('have', 'VB'), ('to', 'TO'), ('wait', 'VB'), ('and', 'CC'), ('see', 'VB'), ('[', 'JJ'), ('end_answer', 'JJR'), (']', 'NN'), ('By', 'IN'), ('fostering', 'VBG'), ('price', 'NN'), ('stability', 'NN'), ('the', 'DT'), ('bank', 'NN'), ('is', 'VBZ'), ('also', 'RB'), ('fostering', 'VBG'), ('economic', 'JJ'), ('growth', 'NN'), ('[', 'NNP'), ('end_answer', 'VBZ'), (']', 'NNP'), ('Carlos', 'NNP'), ('Álvaro', 'NNP'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Frankfurt', 'NNP'), ('Having', 'VBG'), ('recently', 'RB'), ('completed', 'VBD'), ('his', 'PRP$'), ('first', 'JJ'), ('year', 'NN'), ('as', 'IN'), ('a', 'DT'), ('Member', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('ECB', 'NNP'), ('’', 'NNP'), ('s', 'NNP'), ('Executive', 'NNP'), ('Board', 'NNP'), ('José', 'NNP'), ('Manuel', 'NNP'), ('González-Páramo', 'NNP'), ('Madrid', 'NNP'), ('1958', 'CD'), ('is', 'VBZ'), ('interviewed', 'VBN'), ('by', 'IN'), ('LA', 'NNP'), ('GACETA', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('Eurotower', 'NNP'), ('the', 'DT'), ('bank', 'NN'), ('’', 'NNP'), ('s', 'VBZ'), ('Frankfurt', 'NNP'), ('head', 'NN'), ('office', 'NN'), ('His', 'PRP$'), ('message', 'NN'), ('is', 'VBZ'), ('clear', 'JJ'), ('the', 'DT'), ('ECB', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('monetary', 'JJ'), ('policy', 'NN'), ('is', 'VBZ'), ('not', 'RB'), ('stifling', 'VBG'), ('growth', 'NN'), ('–', 'IN'), ('rather', 'RB'), ('it', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('lack', 'NN'), ('of', 'IN'), ('structural', 'JJ'), ('reform', 'NN'), ('He', 'PRP'), ('is', 'VBZ'), ('cautious', 'JJ'), ('about', 'IN'), ('interest', 'NN'), ('rates', 'NNS'), ('Today', 'NN'), ('they', 'PRP'), ('are', 'VBP'), ('appropriate', 'JJ'), ('But', 'CC'), ('the', 'DT'), ('analysis', 'NN'), ('may', 'MD'), ('change', 'VB'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'JJ'), ('González-Páramo', 'NNP'), ('Progress', 'NN'), ('in', 'IN'), ('European', 'JJ'), ('construction', 'NN'), ('has', 'VBZ'), ('had', 'VBN'), ('its', 'PRP$'), ('ups', 'NNS'), ('and', 'CC'), ('downs', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('past', 'JJ'), ('but', 'CC'), ('has', 'VBZ'), ('always', 'RB'), ('pulled', 'VBN'), ('through', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('fully', 'RB'), ('confident', 'JJ'), ('that', 'IN'), ('the', 'DT'), ('process', 'NN'), ('will', 'MD'), ('continue', 'VB'), ('Moreover', 'RB'), ('the', 'DT'), ('climate', 'NN'), ('that', 'WDT'), ('has', 'VBZ'), ('been', 'VBN'), ('generated', 'VBN'), ('does', 'VBZ'), ('not', 'RB'), ('seem', 'VB'), ('to', 'TO'), ('have', 'VB'), ('had', 'VBN'), ('an', 'DT'), ('impact', 'NN'), ('on', 'IN'), ('any', 'DT'), ('important', 'JJ'), ('variable', 'NN'), ('And', 'CC'), ('it', 'PRP'), ('can', 'MD'), ('not', 'RB'), ('affect', 'VB'), ('EMU', 'NNP'), ('or', 'CC'), ('the', 'DT'), ('ECB', 'NNP'), ('’', 'NNP'), ('s', 'JJ'), ('mission', 'NN'), ('to', 'TO'), ('promote', 'VB'), ('confidence', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'JJ'), ('González-Páramo', 'NNP'), ('The', 'DT'), ('conditions', 'NNS'), ('for', 'IN'), ('a', 'DT'), ('gradual', 'JJ'), ('recovery', 'NN'), ('from', 'IN'), ('the', 'DT'), ('currently', 'RB'), ('low', 'JJ'), ('rates', 'NNS'), ('of', 'IN'), ('growth', 'NN'), ('are', 'VBP'), ('in', 'IN'), ('place', 'NN'), ('both', 'DT'), ('internally', 'RB'), ('and ...
# Content 11: [('It', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('difficult', 'JJ'), ('period', 'NN'), ('but', 'CC'), ('I', 'PRP'), ('think', 'VBP'), ('it', 'PRP'), ('is', 'VBZ'), ('an', 'DT'), ('exaggeration', 'NN'), ('to', 'TO'), ('talk', 'VB'), ('of', 'IN'), ('failure', 'NN'), ('The', 'DT'), ('postponement', 'NN'), ('on', 'IN'), ('the', 'DT'), ('budget', 'NN'), ('was', 'VBD'), ('largely', 'RB'), ('expected', 'VBN'), ('even', 'RB'), ('before', 'IN'), ('the', 'DT'), ('referendums', 'NNS'), ('The', 'DT'), ('“', 'NNP'), ('no', 'DT'), ('”', 'NN'), ('to', 'TO'), ('the', 'DT'), ('Constitution', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('much', 'RB'), ('more', 'RBR'), ('serious', 'JJ'), ('matter', 'NN'), ('At', 'IN'), ('least', 'JJS'), ('three', 'CD'), ('motives', 'NNS'), ('lay', 'VBD'), ('behind', 'IN'), ('the', 'DT'), ('French', 'JJ'), ('and', 'CC'), ('the', 'DT'), ('Dutch', 'JJ'), ('vote', 'NN'), ('First', 'NNP'), ('of', 'IN'), ('all', 'RB'), ('there', 'EX'), ('was', 'VBD'), ('a', 'DT'), ('lack', 'NN'), ('of', 'IN'), ('confidence', 'NN'), ('in', 'IN'), ('the', 'DT'), ('respective', 'JJ'), ('governments', 'NNS'), ('The', 'DT'), ('second', 'JJ'), ('reason', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('enlargement', 'NN'), ('of', 'IN'), ('the', 'DT'), ('European', 'NNP'), ('Union', 'NNP'), ('not', 'RB'), ('least', 'JJS'), ('to', 'TO'), ('Turkey', 'NNP'), ('which', 'WDT'), ('seems', 'VBZ'), ('to', 'TO'), ('go', 'VB'), ('on', 'IN'), ('and', 'CC'), ('on', 'IN'), ('and', 'CC'), ('has', 'VBZ'), ('come', 'VBN'), ('about', 'IN'), ('without', 'IN'), ('consulting', 'VBG'), ('the', 'DT'), ('people', 'NNS'), ('in', 'IN'), ('an', 'DT'), ('ever', 'RB'), ('more', 'JJR'), ('political', 'JJ'), ('Europe', 'NNP'), ('where', 'WRB'), ('decisions', 'NNS'), ('are', 'VBP'), ('made', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('majority', 'NN'), ('citizens', 'NNS'), ('must', 'MD'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('choose', 'VB'), ('with', 'IN'), ('which', 'WDT'), ('other', 'JJ'), ('countries', 'NNS'), ('they', 'PRP'), ('wish', 'VBP'), ('to', 'TO'), ('unite', 'VB'), ('themselves', 'PRP'), ('and', 'CC'), ('with', 'IN'), ('whom', 'WP'), ('they', 'PRP'), ('wish', 'VBP'), ('to', 'TO'), ('share', 'NN'), ('the', 'DT'), ('power', 'NN'), ('to', 'TO'), ('decide', 'VB'), ('on', 'IN'), ('issues', 'NNS'), ('which', 'WDT'), ('affect', 'VBP'), ('their', 'PRP$'), ('daily', 'JJ'), ('lives', 'NNS'), ('Finally', 'RB'), ('the', 'DT'), ('third', 'JJ'), ('motive', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('text', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Constitution', 'NNP'), ('itself', 'PRP'), ('which', 'WDT'), ('is', 'VBZ'), ('incomprehensible', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('general', 'JJ'), ('public', 'NN'), ('because', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('written', 'VBN'), ('like', 'IN'), ('an', 'DT'), ('international', 'JJ'), ('treaty', 'NN'), ('[', 'NN'), ('end_answer', 'VBZ'), (']', 'JJ'), ('People', 'NNP'), ('ask', 'NN'), ('that', 'IN'), ('Europe', 'NNP'), ('above', 'IN'), ('all', 'DT'), ('resolve', 'VB'), ('their', 'PRP$'), ('daily', 'JJ'), ('problems', 'NNS'), ('This', 'DT'), ('may', 'MD'), ('require', 'VB'), ('a', 'DT'), ('return', 'NN'), ('to', 'TO'), ('a', 'DT'), ('functionalistic', 'JJ'), ('approach', 'NN'), ('with', 'IN'), ('step-by-step', 'JJ'), ('integration', 'NN'), ('concentrated', 'VBN'), ('on', 'IN'), ('those', 'DT'), ('areas', 'NNS'), ('in', 'IN'), ('which', 'WDT'), ('Europe', 'NNP'), ('can', 'MD'), ('provide', 'VB'), ('effective', 'JJ'), ('solutions', 'NNS'), ('rather', 'RB'), ('than', 'IN'), ('by', 'IN'), ('means', 'NNS'), ('of', 'IN'), ('grand', 'JJ'), ('institutional', 'JJ'), ('designs', 'NNS'), ('even', 'RB'), ('at', 'IN'), ('the', 'DT'), ('expense', 'NN'), ('of', 'IN'), ('overall', 'JJ'), ('consistency', 'NN'), ('Europe', 'NNP'), ('is', 'VBZ'), ('appreciated', 'VBN'), ('by', 'IN'), ('its', 'PRP$'), ('citizens', 'NNS'), ('when', 'WRB'), ('it', 'PRP'), ('succeeds', 'VBZ'), ('in', 'IN'), ('solving', 'VBG'), ('problems', 'NNS'), ('that', 'WDT'), ('can', 'MD'), (' ...
# Content 12: [('Our', 'PRP$'), ('message', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('clear', 'JJ'), ('the', 'DT'), ('current', 'JJ'), ('level', 'NN'), ('of', 'IN'), ('interest', 'NN'), ('rates', 'NNS'), ('is', 'VBZ'), ('in', 'IN'), ('line', 'NN'), ('with', 'IN'), ('maintaining', 'JJ'), ('price', 'NN'), ('stability', 'NN'), ('over', 'IN'), ('the', 'DT'), ('medium', 'JJ'), ('term', 'NN'), ('Our', 'PRP$'), ('latest', 'JJS'), ('assessment', 'NN'), ('confirmed', 'VBD'), ('that', 'IN'), ('underlying', 'VBG'), ('inflationary', 'JJ'), ('pressures', 'NNS'), ('remain', 'VBP'), ('contained', 'JJ'), ('and', 'CC'), ('that', 'DT'), ('inflation', 'NN'), ('is', 'VBZ'), ('projected', 'VBN'), ('to', 'TO'), ('decline', 'VB'), ('over', 'IN'), ('the', 'DT'), ('medium', 'JJ'), ('term', 'NN'), ('There', 'EX'), ('are', 'VBP'), ('however', 'RB'), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), ('upside', 'JJ'), ('risks', 'NNS'), ('to', 'TO'), ('price', 'NN'), ('stability', 'NN'), ('such', 'JJ'), ('as', 'IN'), ('high', 'JJ'), ('and', 'CC'), ('volatile', 'JJ'), ('oil', 'NN'), ('prices', 'NNS'), ('These', 'DT'), ('risks', 'NNS'), ('stem', 'VBP'), ('mainly', 'RB'), ('from', 'IN'), ('potential', 'JJ'), ('second-round', 'JJ'), ('effects', 'NNS'), ('of', 'IN'), ('higher', 'JJR'), ('oil', 'NN'), ('prices', 'NNS'), ('on', 'IN'), ('wages', 'NNS'), ('and', 'CC'), ('prices', 'NNS'), ('Up', 'IN'), ('till', 'RB'), ('now', 'RB'), ('past', 'JJ'), ('oil', 'NN'), ('price', 'NN'), ('increases', 'NNS'), ('had', 'VBD'), ('no', 'DT'), ('significant', 'JJ'), ('effects', 'NNS'), ('on', 'IN'), ('wage', 'NN'), ('developments', 'NNS'), ('inflation', 'NN'), ('expectations', 'NNS'), ('and', 'CC'), ('core', 'NN'), ('inflation', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Yes', 'NNP'), ('they', 'PRP'), ('do', 'VBP'), ('The', 'DT'), ('excess', 'JJ'), ('liquidity', 'NN'), ('accumulated', 'VBN'), ('over', 'IN'), ('the', 'DT'), ('past', 'JJ'), ('few', 'JJ'), ('years', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('acceleration', 'NN'), ('of', 'IN'), ('money', 'NN'), ('and', 'CC'), ('credit', 'NN'), ('growth', 'NN'), ('since', 'IN'), ('the', 'DT'), ('middle', 'NN'), ('of', 'IN'), ('last', 'JJ'), ('year', 'NN'), ('poses', 'VBZ'), ('medium-term', 'JJ'), ('risks', 'NNS'), ('to', 'TO'), ('price', 'NN'), ('stability', 'NN'), ('Stronger', 'JJR'), ('economic', 'JJ'), ('growth', 'NN'), ('in', 'IN'), ('2005', 'CD'), ('and', 'CC'), ('2006', 'CD'), ('could', 'MD'), ('imply', 'VB'), ('an', 'DT'), ('increased', 'VBN'), ('likelihood', 'NN'), ('that', 'DT'), ('inflation', 'NN'), ('risks', 'NNS'), ('associated', 'VBN'), ('with', 'IN'), ('monetary', 'JJ'), ('and', 'CC'), ('credit', 'NN'), ('growth', 'NN'), ('could', 'MD'), ('materialise', 'VB'), ('This', 'DT'), ('prospect', 'NN'), ('requires', 'VBZ'), ('continued', 'JJ'), ('vigilance', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'IN'), ('It', 'PRP'), ('is', 'VBZ'), ('an', 'DT'), ('unpleasant', 'JJ'), ('fact', 'NN'), ('that', 'IN'), ('high', 'JJ'), ('oil', 'NN'), ('prices', 'NNS'), ('pose', 'VBP'), ('simultaneously', 'RB'), ('upside', 'JJ'), ('risks', 'NNS'), ('to', 'TO'), ('inflation', 'NN'), ('and', 'CC'), ('downside', 'NN'), ('risks', 'NNS'), ('to', 'TO'), ('growth', 'NN'), ('Estimates', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('impact', 'NN'), ('of', 'IN'), ('higher', 'JJR'), ('oil', 'NN'), ('prices', 'NNS'), ('on', 'IN'), ('growth', 'NN'), ('and', 'CC'), ('inflation', 'NN'), ('are', 'VBP'), ('surrounded', 'VBN'), ('by', 'IN'), ('uncertainty', 'NN'), ('and', 'CC'), ('must', 'MD'), ('be', 'VB'), ('interpreted', 'VBN'), ('with', 'IN'), ('caution', 'NN'), ('Having', 'VBG'), ('stressed', 'VBN'), ('this', 'DT'), ('I', 'PRP'), ('can', 'MD'), ('say', 'VB'), ('that', 'IN'), ('the', 'DT'), ('average', 'NN'), ('estimated', 'VBD'), ('effect', 'NN'), ('of', 'IN'), ('an', 'DT'), ('oil', 'NN'), ('price', 'NN'), ('increase', 'NN'), ('of', 'IN'), ('10', 'CD'), ('%', 'NN'), ('is', 'VBZ'), ('to', 'TO'), ('add', 'VB'), ('about', 'IN'), ('0.1', 'CD'), ('percentage', ...
# Content 13: [('[', 'NN'), ('Answer', 'NNP'), (']', 'NNP'), ('I', 'PRP'), ('believe', 'VBP'), ('that', 'IN'), ('Europe', 'NNP'), ('needs', 'VBZ'), ('to', 'TO'), ('redouble', 'VB'), ('its', 'PRP$'), ('efforts', 'NNS'), ('to', 'TO'), ('become', 'VB'), ('more', 'RBR'), ('competitive', 'JJ'), ('Failure', 'NN'), ('to', 'TO'), ('do', 'VB'), ('so', 'RB'), ('would', 'MD'), ('be', 'VB'), ('very', 'RB'), ('costly', 'JJ'), ('The', 'DT'), ('ECB', 'NNP'), ('fully', 'RB'), ('subscribes', 'VBZ'), ('to', 'TO'), ('the', 'DT'), ('substance', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Lisbon', 'NNP'), ('agenda', 'NN'), ('the', 'DT'), ('aim', 'NN'), ('of', 'IN'), ('which', 'WDT'), ('is', 'VBZ'), ('to', 'TO'), ('turn', 'VB'), ('the', 'DT'), ('European', 'NNP'), ('Union', 'NNP'), ('into', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('competitive', 'JJ'), ('market', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('by', 'IN'), ('2010', 'CD'), ('–Il', 'JJ'), ('Sole-24', 'NNP'), ('Oreeditor', 'NNP'), ("'s", 'POS'), ('note', 'NN'), ('and', 'CC'), ('to', 'TO'), ('the', 'DT'), ('European', 'NNP'), ('Commission', 'NNP'), ("'s", 'POS'), ('wish', 'JJ'), ('to', 'TO'), ('press', 'VB'), ('on', 'IN'), ('in', 'IN'), ('this', 'DT'), ('direction', 'NN'), ('in', 'IN'), ('line', 'NN'), ('with', 'IN'), ('the', 'DT'), ('recent', 'JJ'), ('report', 'NN'), ('on', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('issue', 'NN'), ('put', 'VBD'), ('together', 'RB'), ('by', 'IN'), ('former', 'JJ'), ('Netherlands', 'NNP'), ('Prime', 'NNP'), ('Minister', 'NNP'), ('Wim', 'NNP'), ('Kok', 'NNP'), ('A', 'DT'), ('good', 'JJ'), ('deal', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('done', 'VBN'), ('but', 'CC'), ('we', 'PRP'), ('believe', 'VBP'), ('that', 'IN'), ('a', 'DT'), ('great', 'JJ'), ('deal', 'NN'), ('more', 'RBR'), ('can', 'MD'), ('still', 'RB'), ('be', 'VB'), ('done', 'VBN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('Answer', 'NNP'), (']', 'VBD'), ('The', 'DT'), ('lag', 'NN'), ('that', 'WDT'), ('has', 'VBZ'), ('built', 'VBN'), ('up', 'RP'), ('between', 'IN'), ('Europe', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('in', 'IN'), ('terms', 'NNS'), ('of', 'IN'), ('productivity', 'NN'), ('growth', 'NN'), ('since', 'IN'), ('the', 'DT'), ('mid-1990s', 'NN'), ('is', 'VBZ'), ('partially', 'RB'), ('due', 'JJ'), ('to', 'TO'), ('a', 'DT'), ('lack', 'NN'), ('of', 'IN'), ('structural', 'JJ'), ('reform', 'NN'), ('It', 'PRP'), ('is', 'VBZ'), ('not', 'RB'), ('our', 'PRP$'), ('intention', 'NN'), ('to', 'TO'), ('play', 'VB'), ('down', 'RP'), ('the', 'DT'), ('difficulties', 'NNS'), ('in', 'IN'), ('reforming', 'VBG'), ('the', 'DT'), ('economy', 'NN'), ('or', 'CC'), ('in', 'IN'), ('persuading', 'VBG'), ('society', 'NN'), ('of', 'IN'), ('the', 'DT'), ('need', 'NN'), ('for', 'IN'), ('what', 'WP'), ('are', 'VBP'), ('sometimes', 'RB'), ('unpopular', 'JJ'), ('measures', 'NNS'), ('but', 'CC'), ('we', 'PRP'), ('also', 'RB'), ('know', 'VBP'), ('that', 'IN'), ('new', 'JJ'), ('reforms', 'NNS'), ('will', 'MD'), ('help', 'VB'), ('to', 'TO'), ('boost', 'VB'), ('economic', 'JJ'), ('growth', 'NN'), ('European', 'JJ'), ('prosperity', 'NN'), ('and', 'CC'), ('employment', 'NN'), ('In', 'IN'), ('this', 'DT'), ('sense', 'NN'), ('the', 'DT'), ('ECB', 'NNP'), ('backs', 'VBZ'), ('governments', 'NNS'), ('and', 'CC'), ('all', 'DT'), ('social', 'JJ'), ('partners', 'NNS'), ('in', 'IN'), ('their', 'PRP$'), ('efforts', 'NNS'), ('to', 'TO'), ('introduce', 'VB'), ('these', 'DT'), ('measures', 'NNS'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('Answer', 'NNP'), (']', 'NNP'), ('You', 'PRP'), ('are', 'VBP'), ('right', 'JJ'), ('The', 'DT'), ('Governing', 'NNP'), ('Council', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('ECB', 'NNP'), ('has', 'VBZ'), ('to', 'TO'), ('look', 'VB'), ('at', 'IN'), ('the', 'DT'), ('region', 'NN'), ('as', 'IN'), ('a', 'DT'), ('whole', 'NN'), ('in', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('way', 'NN'), ('as', 'IN'), ('the', 'DT'), ('Federal', 'NNP'), ('Reser ...
# Content 14: [('English', 'JJ'), ('translation', 'NN'), ('of', 'IN'), ('an', 'DT'), ('interview', 'NN'), ('published', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('edition', 'NN'), ('of', 'IN'), ('Il', 'NNP'), ('Sole', 'NNP'), ('24', 'CD'), ('Ore', 'NNP'), ('dated', 'VBD'), ('17', 'CD'), ('February', 'NNP'), ('2005', 'CD'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NNP'), ('Currently', 'NNP'), ('the', 'DT'), ('European', 'JJ'), ('economy', 'NN'), ('is', 'VBZ'), ('growing', 'VBG'), ('at', 'IN'), ('faster', 'RBR'), ('a', 'DT'), ('rate', 'NN'), ('than', 'IN'), ('that', 'DT'), ('recorded', 'VBN'), ('in', 'IN'), ('2003', 'CD'), ('2002', 'CD'), ('and', 'CC'), ('2001', 'CD'), ('but', 'CC'), ('this', 'DT'), ('growth', 'NN'), ('is', 'VBZ'), ('accompanied', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('sluggishness', 'NN'), ('in', 'IN'), ('particular', 'JJ'), ('in', 'IN'), ('consumption', 'NN'), ('above', 'IN'), ('all', 'DT'), ('in', 'IN'), ('Italy', 'NNP'), ('and', 'CC'), ('Germany', 'NNP'), ('In', 'IN'), ('this', 'DT'), ('respect', 'NN'), ('the', 'DT'), ('situation', 'NN'), ('has', 'VBZ'), ('not', 'RB'), ('improved', 'VBN'), ('compared', 'VBN'), ('with', 'IN'), ('three', 'CD'), ('months', 'NNS'), ('ago', 'RB'), ('Although', 'IN'), ('it', 'PRP'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('said', 'VBD'), ('that', 'IN'), ('growth', 'NN'), ('is', 'VBZ'), ('strengthening', 'VBG'), ('neither', 'CC'), ('can', 'MD'), ('it', 'PRP'), ('be', 'VB'), ('described', 'VBN'), ('as', 'IN'), ('having', 'VBG'), ('petered', 'VBN'), ('out', 'RP'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'IN'), ('We', 'PRP'), ('do', 'VBP'), ('not', 'RB'), ('really', 'RB'), ('know', 'VB'), ('why', 'WRB'), ('this', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('case', 'NN'), ('The', 'DT'), ('low', 'JJ'), ('levels', 'NNS'), ('of', 'IN'), ('growth', 'NN'), ('in', 'IN'), ('Italy', 'NNP'), ('and', 'CC'), ('Germany', 'NNP'), ('have', 'VBP'), ('certain', 'JJ'), ('common', 'JJ'), ('features', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('long', 'JJ'), ('duration', 'NN'), ('demographic', 'JJ'), ('decline', 'NN'), ('consumer', 'NN'), ('weakness', 'NN'), ('the', 'DT'), ('existence', 'NN'), ('of', 'IN'), ('a', 'DT'), ('large', 'JJ'), ('region', 'NN'), ('with', 'IN'), ('an', 'DT'), ('assisted', 'JJ'), ('economy', 'NN'), ('which', 'WDT'), ('burdens', 'VBZ'), ('public', 'JJ'), ('accounts', 'NNS'), ('and', 'CC'), ('does', 'VBZ'), ('not', 'RB'), ('succeed', 'VB'), ('in', 'IN'), ('taking', 'VBG'), ('off', 'RP'), ('the', 'DT'), ('Mezzogiorno', 'NNP'), ('in', 'IN'), ('Italy', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('East', 'NNP'), ('in', 'IN'), ('Germany', 'NNP'), ('However', 'RB'), ('there', 'EX'), ('are', 'VBP'), ('also', 'RB'), ('differences', 'NNS'), ('For', 'IN'), ('example', 'NN'), ('in', 'IN'), ('recent', 'JJ'), ('years', 'NNS'), ('Germany', 'NNP'), ('has', 'VBZ'), ('made', 'VBN'), ('a', 'DT'), ('formidable', 'JJ'), ('recovery', 'NN'), ('in', 'IN'), ('terms', 'NNS'), ('of', 'IN'), ('its', 'PRP$'), ('competitivity', 'NN'), ('while', 'IN'), ('Italy', 'NNP'), ('has', 'VBZ'), ('lost', 'VBN'), ('ground', 'NN'), ('[', 'NN'), ('end_answer', 'NN'), (']', 'NN'), ('There', 'EX'), ('is', 'VBZ'), ('nothing', 'NN'), ('new', 'JJ'), ('in', 'IN'), ('emphasizing', 'VBG'), ('the', 'DT'), ('abundance', 'NN'), ('of', 'IN'), ('liquidity', 'NN'), ('For', 'IN'), ('several', 'JJ'), ('years', 'NNS'), ('now', 'RB'), ('our', 'PRP$'), ('monetary', 'JJ'), ('analysis', 'NN'), ('has', 'VBZ'), ('revealed', 'VBN'), ('significant', 'JJ'), ('growth', 'NN'), ('in', 'IN'), ('liquidity', 'NN'), ('Exceptionally', 'RB'), ('low', 'JJ'), ('interest', 'NN'), ('rates', 'NNS'), ('have', 'VBP'), ('pushed', 'VBN'), ('investors', 'NNS'), ('towards', 'NNS'), ('certain', 'JJ'), ('forms', 'NNS'), ('of', 'IN'), ('investment', 'NN'), ('and', 'CC'), ('have', 'VBP'), ('led', 'VBN'), ('to', 'TO'), ('a', 'DT'), ('strong', 'JJ'), ('increase', 'NN'), ('in', 'IN'), ('prices', 'NNS'), ('in', 'IN'), ('certain', 'JJ'), ('asset', 'NN'), ('markets', 'NNS'), ('principally', 'RB' ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/NLP/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 14
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/mathieu26/Desktop/DSDM-BSE/Thesis/ECB_2/DSDM_Thesis/EDA.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/Users/mathieu26/Desktop/DSDM-BSE/Thesis/ECB_2/DSDM_Thesis/EDA.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> aux_functions.print_contents(df,20, "pos_tags")
#
# File ~/Desktop/DSDM-BSE/Thesis/ECB_2/DSDM_Thesis/aux_functions.py:18, in print_contents(df, n, column_name)
#      16 for i in range(n):
#      17     if i < len(df[column_name]):
# ---> 18         print(f"Content {i+1}: {df[column_name][i]}")
#      19     else:
#      20         print(f"Content {i+1}: Index out of range.")
#
# File ~/anaconda3/envs/NLP/lib/python3.11/site-packages/pandas/core/series.py:1112, in Series.__getitem__(self, key)
#    1109     return self._values[key]
#    1111 elif key_is_scalar:
# -> 1112     return self._get_value(key)
#    1114 # Convert generator to list before going through hashable part
#    1115 # (We will iterate through the generator there to check for slices)
#    1116 if is_iterator(key):
#
# File ~/anaconda3/envs/NLP/lib/python3.11/site-packages/pandas/core/series.py:1228, in Series._get_value(self, label, takeable)
#    1225     return self._values[label]
#    1227 # Similar to Index.get_value, but we do not fall back to positional
# -> 1228 loc = self.index.get_loc(label)
#    1230 if is_integer(loc):
#    1231     return self._values[loc]
#
# File ~/anaconda3/envs/NLP/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 14

# %% [markdown]
# + NN: Noun, singular or mass (e.g., cat, tree)
# + NNS: Noun, plural (e.g., cats, trees)
# + NNP: Proper noun, singular (e.g., John, London)
# + NNPS: Proper noun, plural (e.g., Americans, Carolinas)
# + PRP: Personal pronoun (e.g., I, he, she)
# + PRP$: Possessive pronoun (e.g., my, his, her)
# + RB: Adverb (e.g., very, quickly, often)
# + RBR: Adverb, comparative (e.g., better, faster)
# + RBS: Adverb, superlative (e.g., best, fastest)
# + VB: Verb, base form (e.g., take, live)
# + VBD: Verb, past tense (e.g., took, lived)
# + VBG: Verb, gerund or present participle (e.g., taking, living)
# + VBN: Verb, past participle (e.g., taken, lived)
# + VBP: Verb, non-3rd person singular present (e.g., take, live)
# + VBZ: Verb, 3rd person singular present (e.g., takes, lives)
# + JJ: Adjective (e.g., big, happy)
# + JJR: Adjective, comparative (e.g., bigger, happier)
# + JJS: Adjective, superlative (e.g., biggest, happiest)
# + DT: Determiner (e.g., the, a, some)
# + IN: Preposition or subordinating conjunction (e.g., in, under, although)
# + CC: Coordinating conjunction (e.g., and, but, or)
# + MD: Modal (e.g., can, will, must)
# + WP: Wh-pronoun (e.g., who, what)
# + WDT: Wh-determiner (e.g., which, whatever)
# + WRB: Wh-adverb (e.g., where, when)

# %% [markdown]
# Frequency Analysis of POS Tags

# %%
def count_pos_tags(df):
    # Initialize a Counter to accumulate tag counts
    tag_counts = Counter()

    # Iterate over each row's pos_tags to count each tag
    for index, row in df.iterrows():
        tags = [tag for word, tag in row['pos_tags']]
        tag_counts.update(tags)

    return tag_counts

# Count tags for the entire DataFrame
overall_tag_counts = count_pos_tags(df)
print("Overall POS Tag Counts:", overall_tag_counts)
# Out:
# Overall POS Tag Counts: Counter({'NN': 141003, 'IN': 98464, 'DT': 86490, 'JJ': 72321, 'NNS': 46059, 'RB': 43760, 'PRP': 37176, 'VB': 34474, 'NNP': 32881, 'VBP': 29067, 'VBZ': 28795, 'CC': 25562, 'TO': 23101, 'VBN': 16695, 'MD': 14557, 'VBG': 13787, 'VBD': 11564, 'CD': 8411, 'PRP$': 8408, 'WDT': 6114, 'JJR': 4233, 'WRB': 3977, 'EX': 3509, 'WP': 2848, 'RBR': 2352, 'RP': 1659, 'JJS': 1035, 'NNPS': 702, 'PDT': 686, 'RBS': 454, 'UH': 171, 'FW': 169, 'POS': 160, 'WP$': 32, 'LS': 3, 'SYM': 3})

# %% [markdown]
# 2.2. Noun phrase extraction using Textblob

# %%
#!pip install textblob
#!python -m textblob.download_corpora  # This downloads the necessary corpora for features like noun phrase extraction.

# %%
def extract_noun_phrases(text):
    blob = TextBlob(text)
    return blob.noun_phrases

# %%
# Apply the noun phrase extraction function to each row in the 'contents' column
df['noun_phrases'] = df['contents'].apply(extract_noun_phrases)
# Out:
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_884/3542713608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['noun_phrases'] = df['contents'].apply(extract_noun_phrases)

# %%
aux_functions.print_contents(df,20, "noun_phrases")
# Out:
# Content 1: ['central banks', 'inflation trajectory', 'monetary policy action', 'monetary', 'monetary policy transmission everywhere', 'sharp deceleration', 'weak construction activity', 'inflation expectations', 'inflation shock', 'monetary policy action', 'inflation reflects', 'supply-side shocks', 'monetary policy', 'consumer prices', 'doesn ’ t', 'monetary policy act', 'ecb', 'september', 'doesn ’ t', 'full impact', 'rate rises', 'policy transmission', 'supply-side shocks', 'october', 'critical phase', 'monetary policy', 'final part', 'hardest part', 'disinflationary process', 'sharp decline', 'real wages', 'strong growth', 'nominal wages', 'services sector', 'dominant role', 'cost structure', 'broad scale', 'productive workers', 'public sector employment', 'strong rise', 'nominal wages', 'high growth', 'unit labour costs', 'does', 'crucial question', 'will', 'unit labour costs', 'consumer prices', 'monetary policy', 'aggregate demand', 'monetary policy', 'price expectations', '’ s', 'sticky services inflation', 'resilient labour market', 'financial conditions', 'central banks ’ pivot', 'recent events', 'red sea', 'chain disruptions', 'taken', 'policy stance', 'historical experience', 'recent research paper', 'monetary', 'initial shock', '’ s', 'euro area', 'past year', 'pmi', 'citigroup', 'surprise index', 'policy transmission', 'monetary policy', 'online portals', 'mortgage rates', 'germany', '’ s', 'policy stance', 'substantial progress', 'good news', 'mathematical equations', 'policy decisions', 'different parts', 'recent surge', 'european inflation', 'shocks fade', 'europe', 'low inflation', 'low growth environment', 'past decade', 'supply-side shocks', 'euro area', 'important role', 'pent-up demand', '’ s', 'europe', 'secular stagnation type', 'longer-term developments', 'government action', 'main questions', 'benign scenario', 'benign scenario', 'economic growth', 'increase inflationary pressures', 'certain metals', 'inflation', 'food prices', 'extreme weather events', 'benign scenario', 'economic growth', 'capital stock', 'low-inflation environment', 'benign scenario', 'governments delay', 'green transition', 'political pushbacks', 'low growth', 'stagflationary scenario', 'low growth', 'high inflation', 'eventually', 'economies need', 'long-term growth prospects', 'massive demographic challenge', 'geopolitical shifts', 'real neutral rate', 'r-star', 'real rate', 'steady state', 'borrowing costs', 'neutral rate', 'recent years', 'r-star', 'appropriate calibration', 'monetary policy', 'paul samuelson', "'s monkey", 'interesting paper', 'sebastian hillenbrand', 'harvard', 'business school shows', 'secular decline', 'us government yields', 'narrow time windows', 'federal reserve ’ s', 'monetary policy meetings', 'r-star', 'markets extract information', 'public communication', 'central bankers', 'hence', 'r-star', 'long-run decline', 'r-star', 'global savings glut', 'important factor', 'downward trend', 'good reasons', 'r-star', 'post-financial crisis period', '’ s', 'inflation reduction', 'china', 'significant increase', 'global investment', 'green transition', 'new climate conditions', 'government debt', 'important factor', 'defence spending', 'government debt', 'r-star', 'regards demographic', 'r-star', 'long-term care', 'high investments', 'savings glut', 'global financial markets', 'r-star', 'r-star', 'r-star', 'interest rates', 'rates –', 'small steps', 'inflation proves sticky', 'clear picture', 'monetary policy', 'past year', 'important focus', 'german central bankers ’ hearts', 'european central banker', 'german citizen', 'simple one-to-one relationship', 'money growth', 'different periods', 'ecb', '’ s asset purchase programme', 'central bank reserves – base money –', 'low inflation environment', 'balance sheets', 'global financial crisis', 'euro area sovereign debt crisis', 'inflation', 'ecb', 'balance sheets', 'government support', 'strong loan growth', 'economic contraction', 'world war', 'ii', 'early warnin ...
# Content 2: ['newspaper refers', 'september', 'november', 'ecb', 'proper requirements', 'coming', 'ecb', 'inner workings', 'climate risks', 'don ’ t', 'climate risks', 'banks endanger', 'credit risks', 'agricultural sector', 'risk heightens', 'credit risk', 'transition risk', 'counter climate', 'netherlands', 'office buildings', 'energy label c', 'imagine', 'lent funds', 'valid energy label –', 'credit risk', 'amsterdam', 'companies don ’ t', 'good time', 'legal side', 'elderson', 'dutch', 'environmental organisation', 'milieudefensie', 'ing', 'climate crisis', 'multi-billion loans', 'ing', 'greenhouse gases', 'swedish', 'milieudefensie', 'elderson', 'legal risks', 'affects price stability', 'crop yields', 'ecb', 'research shows', 'food price inflation', '% point', 'rhine', 'measurable decline', 'gdp', 'slovenia', 'august', 'slovenian', 'gdp', 'energy transition', 'high demand', 'affects price stability', 'ecb', 'critics', 'ecb', 'doesn ’ t', 'climate policy', '’ s', 'climate policy', 'climate legislation politicians', 'don', '’ t', 'primary objective – price stability –', '’ s', 'eu treaties', 'doesn ’ t endanger price stability', 'economic policies', 'european union', 'european climate plans', 'treaties', 'ecb', 'free trade', 'gender equality', 'don ’ t', 'ecb', '’ ve', 'don ’ t', 'climate policy', 'top priority', 'brussels', 'eu', 'economic policies', '’ s', 'paris agreement', 'climate', 'deal', '– whereas', '’ re', '’ s', 'ecb', 'clear targets', 'recent years inflation', '% target', 'aren ’ t', '’ s', 'price stability', 'climate risks', 'slovenia', 'national income', 'ignore rises', 'food prices', 'didn ’ t care', '’ ve', '’ re', '’ re making good progress', 'federal reserve', 'jerome powell', 'attitude “', 'trade ”', 'monetary policy', '’ t', 'financial system', 'ignore climate', 'nature crises', 'governments ’ transition plans', '’ s net zero', 'wouldn ’ t', 'greenhouse gases', '’ ve', 'oil markets', 'energy prices', 'monetary policy', 'world making', 'entire energy economy', 'powell', 'price stability', '’ s']
# Content 3: ['mr', 'guindos', 'germany', 'entire euro area economy', 'ecb', 'weak growth', 'euro area', 'noticeable slowdown', 'global trade', 'ecb', '’ s', 'monetary policy', 'policy rates', 'costs increase', 'consumer spending', 'turn slows', 'price increases', '’ s', 'monetary policy', 'economic growth', 'interest rates', 'monetary', 'interest rates', 'real economy –', 'consumer spending', 'investment −', 'research shows', 'full effect', 'interest rate increases', 'recent interest rate', 'personal estimate', 'real economy', '’ t', 'germany', 'eu', 'building applications', 'collateral damage', 'monetary policy', 'main tool', 'interest rates', 'different interest rates', 'different economic sectors', 'real estate market', 'interest rates', 'low interest rate era', 'good thing', 'targeted', 'fiscal policy', 'address construction', 'interest rates', 'please', 'don ’ t', 'inflation abates', 'wages increase', 'people regain', 'consumer spending', 'economic recovery', 'growth prospects', 'euro area', 'germany', 'december', 'euro area', 'world trade', 'geopolitical uncertainties', 'interest rate hikes', 'euro area', 'march', 'germany', 'german economy', 'energy crisis', 'germany', 'euro area', 'german economy', 'china', 'china', 'germany', '’ s economy', 'industrial countries', 'spain', 'early 2000s', 'germany', 'sick man', 'europe', 'wouldn ’ t', 'major problems', 'germany', 'structural problems', 'china', '’ s future growth', 'german firms', 'germany', 'euro', 'area inflation', 'december', 'ecb', '’ s target', 'according', 'december', 'inflation figures', 'positive surprises', 'your', 'does', 'wouldn ’ t', '’ s', 'ecb', 'price', 'kingdom', 'inflation rate', 'medium term', 'turn pushes inflation', 'wage-price spiral', 'competitiveness', 'international comparison', 'central bank', 'ecb', 'interest rates', 'don ’ t', 'december', 'bond buying programmes', 'monetary policy', 'months inflation', 'deep recession', 'delicate situation', 'good situation', 'labour market', 'europe', 'monetary policy', 'energy prices', 'chain bottlenecks', 'monetary policy', 'interest rates', 'ecb', 'greece', 'italy', 'high rates', 'european debt crisis', 'greece', 'italy', 'portugal', 'spain', '’ m', 'european debt crisis', 'economy minister', 'spain', 'wolfgang schäuble', 'schäuble', 'german minister', '’ m', 'wolfgang', 'greece', 'spain', 'ireland', 'italy', 'portugal', 'fix government budgets', 'policy recommendations', 'economic performance', 'southern european countries', 'northern neighbours']
# Content 4: ['franco-german', 'young member', 'bundestag', 'wolfgang schäuble', 'baden-alsace', 'discussion group', 'colmar', 'joseph rey', 'campaign appearances', 'pro-european parliamentary candidates', 'alsace', 'lorraine', 'born', 'french occupation zone', 'border region', 'baden', 'france', 'life –', 'europe', 'wolfgang schäuble', 'french counterparts', 'french cabinet', 'élysée palace', 'european interests', 'europe', 'germany', 'europe', 'germany', 'german unity', 'european integration', 'joint security', 'strong euro', 'stability –', 'fundamental convictions', 'bundestag', 'wolfgang schäuble', 'french national assembly', 'richard ferrand', 'franco-german parliamentary', 'march', 'paris', 'joint chamber', 'french members', 'franco-german parliamentary accord', 'élysée treaty –', 'parliamentary dimension', 'franco-german', 'intergovernmental agreement', 'new level', 'wolfgang schäuble', '’ s', 'paris', 'interview –', 'december', 'wolfgang schäuble', 'weimar triangle', 'german-polish-french', 'europe', 'europe', '’ s defence capabilities', '’ s', 'european path', 'europe', 'environmental role', 'world. “', 'state memorial ceremony', 'january', 'franco-german', 'day ” –', 'élysée treaty', 'wolfgang schäuble', 'bundestag', 'french national assembly', 'january', 'franco-german', 'courageous people', 'world wars', 'germany', 'wolfgang schäuble', 'original signatories', 'together', 'wolfgang schäuble', 'state memorial ceremony', 'bundestag', 'emmanuel macron', 'great merit', 'european vision', 'young people', 'europe', 'european integration', 'determination –', 'wolfgang schäuble', 'wolfgang schäuble', "'s memory", 'immense gratitude', "life 's work", 'german', 'great friend', 'france', 'thank', 'wolfgang schäuble']
# Content 5: ['september', 'ecb', 'inflation target', 'extra insurance', 'encouraging data', 'extra insurance', 'recent months', 'individual hikes', 'september', 'interest rate', 'ecb', 'restrictive policy', 'inflation expectations', 'moderate price setting', 'ecb', 'interest rates', 'rate cuts', 'september', 'peak rate', 'insurance element', 'rate adjustment', 'neutral monetary policy stance', 'ecb', 'rate cuts', 'march', 'april', 'market discounts euro area recession', 'german budget', 'ecb', 'staff projections', 'inflation release', 'december', 'projections –', '’ m', 'major downside surprise', 'core inflation', 'services inflation', 'long-run equilibrium rate', 'don ’ t', 'energy prices', 'baseline staff projections', 'significant recovery', 'european economy', 'europe', 'own terms', 'december', 'downside risks', 'big data questions', 'peak', 'monetary policy restriction', 'fiscal policy', 'euro area economies', 'december', 'draft budgetary plans', 'euro area countries', 'support measures', 'energy measures', 'german court ruling', 'germany', 'inflation outlook', 'ecb', 'assess wage settlements', 'monetary policy', 'wage deals', 'april', 'wage settlements', 'wage tracker measure', 'early indication', 'wage dynamics', 'market data', 'complete dataset', 'eurostat', 'national accounts data', 'april', 'june', 'important data', 'good understanding', 'wage settlements', 'high wage increases', 'high inflation', 'rate adjustment', 'euro-area countries', 'serious drops', 'real wages', 'germany', 'italy', 'compatible wage settlement', 'productivity growth', 'power losses', 'whole euro area', 'labour productivity', 'wage increase consistent', 'cent inflation target', 'wage increases', 'percentage point', 'high inflation', 'multi-year process', 'large wage increases', 'wage-price spiral', '’ s', 'gradual process', 'italian government', 'ecb', '’ s', 'inflation situation', 'significant disinflation', 'atypical factors', 'monetary policy', 'euro area', 'russia', '’ s aggression', 'ukraine', '’ s', 'interest rate rises', 'supply shock', 'high level', 'high inflation', 'interest rates', 'government politicians', 'italy', 'government budget', 'monetary policy', 'ecb', 'doesn ’ t', 'ecb', 'long-term interest rate', 'ten-year bonds', 'cyclical increase', 'interest rates', '’ s', 'normalise interest rates', 'government debt', 'inflation problem', 'high inflation episodes', 'central banks', 'inflation wave', 'interest rate hikes', '’ s', '’ s', 'false dawn', 'don ’ t', 'hold-steady position', 'september', 'active normalisation', 'important discussion', '’ s', 'sufficient evidence', 'italy', 'esm', 'treaty reform', 'banking', '’ s', 'europe', 'europe', 'green transition', 'generation eu', 'italy', 'esm', 'single resolution', 'europe', 'russian official reserves', 'ukrainian', 'viable course', 'political leaders', '’ s', 'international monetary system', 'financial stability', 'legal foundations', 'international system', '’ s', 'risk factors', 'decision-making process', 'international reserve currency', 'full analysis', '’ m', 'different policy teams', '’ s', 'decision process', 'eu', 'new fiscal framework', '’ s', 'final result', 'fiscal framework', 'consensual agreement', 'eu', 'compromise reflects', 'new framework', 'numerical guardrails', 'only kick', 'various sub-scenarios', 'baseline scenario', 'commission proposal', 'baseline guidance', 'fiscal policy', 'multi-year approaches', 'fiscal adjustment', 'multi-year horizons', '’ s', 'fiscal framework', 'aren', '’ t', 'debt ratios', '’ s', 'red sea crisis', 'possible new attacks', 'oil tankers', 'strait', 'hormuz', 'western bombing', 'houthi', 'economic repercussions', 'europe', '’ s', 'shipping routes', 'longer-term problem', 'world trade', 'new type', 'unwelcome bottleneck', 'different effects', 'mechanically', 'disinflationary effect', 'postpone investments', 'geopolitical risks']
# Content 6: ['hi', 'isabel_schnabel', 'executive board member', 'ecb', 'please', 'askecb who', '% inflation', 'isabel_schnabel', 'ecb', 'strategy review', '% target', 'price stability', 'deflation risks', 'interest rates', '8f9fbedf46f0b7ecf0ac42473109e11a #', 'askecb', 'august', 'central banks', 'sacrifice ratio', 'historical lows', 'askecb', 'isabel_schnabel', 'phillips', 'sacrifice ratio', 'new evidence suggests', '//www.ecb.europa.eu/press/key/date/2023/html/ecb.sp230831~c25314a3fc.en.html #', 'askecb', 'askecb', 'tpi', 'ecb', 'political landscape', 'eu', 'populist spending', 'normal mechanism', 'ecb', "'s remit", 'isabel_schnabel', 'tpi', 'market dynamics', 'monetary policy transmission', 'euro area', 'eligibility', 'countries pursue', 'macroeconomic policies', 'askecb', 'askecb', 'large group', 'ecb', 'ecb', 'isabel_schnabel', 'ecb', 'diversity', 'current board', 'governing', 'council display', 'broad range', 'askecb', 'own sovereign currency', 'print money', 'key strokes', 'don ’ t', 'ol ’', 'myth', 'askecb', 'isabel_schnabel', 'large majority', 'independent central banks', '“ print money ”', 'askecb', 'askecb', 'eurozone', 'unemployment rate', 'november', 'wage growth', 'isabel_schnabel', 'historical low confirms', 'strong resilience', 'labour markets', 'december', 'staff projections', 'gradual decline', 'wage growth', 'askecb', 'new fiscal rules', 'fiscal policy', 'monetary policy', 'germany', 'numerical targets', 'eu', 'fiscal rules', 'debt brake', 'askecb', 'isabel_schnabel', 'new fiscal rules', 'right direction', 'member states', 'public investment', 'new framework lacks', 'central fiscal capacity', 'askecb', 'askecb récent', 'central bank pivot', 'substantial rates rally', 'eurozone', 'survey data', 'does', 'inflation reacceleration', 'growth/inflation', 'thank', 'isabel_schnabel', 'sentiment indicators', 'economic outlook', 'financial conditions', 'energy prices', 'askecb', 'bitcoin', 'euro cbdc', 'askecb', 'isabel_schnabel', 'digital euro', 'public money', 'european central bank', 'bitcoin', 'different –', 'speculative asset', 'askecb ecb', "market 's bets", 'current pricing', 'rate cuts', 'march/april', 'ecb', 'askecb', 'isabel_schnabel', 'markets', 'reaction function', 'different views', 'future economic developments', 'inflation outlook', 'askecb inflation', 'ecb', 'geopolitical risks', 'red sea', 'euro area', 'askecb', 'isabel_schnabel', '% target', 'right track', 'geopolitical', 'upside risks', 'energy prices', 'freight costs', '’ s', 'askecb', 'ecb', 'main reason', 'current recessionary context', 'europe', 'askecb', 'isabel_schnabel', 'inflation', 'price pressures', 'policy', 'rates need', 'monetary policy transmission', 'askecb wie', 'sie', 'notenbanken staatsanleihen', 'kaufen und', 'bilanz', 'isabel_schnabel', 'purchases', 'government bonds', 'useful monetary policy tool', 'price stability', 'policy rates', 'monetary policy transmission', 'march', 'bond holdings', 'askecb', 'isabel_schnabel', 'anleihekäufe', 'können ein nützliches geldpolitisches', 'instrument', 'preisstabilität', 'zu sichern', 'zinsen', 'nahe ihrer', 'untergrenze', 'oder um', 'transmission', 'zu schützen', 'seit märz', 'reduzieren wir unsere', 'anleihebestände', 'askecb warum', 'wurde der', 'anteil', 'mietkosten', 'nebenkosten', 'warenkorb', 'reduziert obwohl', 'kosten', 'rental costs', 'additional costs', 'isabel_schnabel', 'hicp', 'consumption basket', 'average household spending', 'weights', 'eurostat', 'national authorities', 'askecb', 'isabel_schnabel', 'die gewichte', 'hvpi-warenkorb', 'werden über den', 'anteil', 'den durchschnittlichen', 'haushaltsausgaben', 'sie', 'werden zu', 'jahresbeginn', 'eurostat', 'gemeinsam mit den nationalen', 'behörden', 'askecb', 'ecb', 'buying bitcoin', 'balance sheet', 'isabel_schnabel', 'ecb', 'bitcoin', 'askecb', 'askecb', 'overall indicators', 'ecb', 'powell', 'inflation raises', 'restrictive policy', 'ecb', 'isabel_schnabel', 'crucial', 'monetary policy', 'financial conditions', 'askecb dazu',  ...
# Content 7: ['wolfgang schäuble', 'french cabinet', 'élysée palace', 'brussels', 'straight talker', 'difficult decisions', 'public servant', 'intellectual ability', 'natural statesman', 'dear friend', 'colleague saddens', 'remarkable achievements', 'europe', 'own words', 'clear commitment', 'germany', 'europe', 'europe', 'germany', 'europe', 'germany.', 'few', 'germany', 'europe', 'long period', 'wolfgang', 'public service', 'germany', '’ s reunification process', 'europeans', 'great care', 'german history', 'wolfgang', 'germany', 'europe', 'small matter', 'deutsche mark', 'europe', 'competitive devaluations', 'germany', '’ s', 'europe', '’ s', 'europe', '’ s sovereign debt crisis', 'wolfgang', 'europe', 'wolfgang', '’ s', 'intellectual rigour', 'european framework', '’ s', 'challenging environment', 'forceful personality', 'common ground', 'germany', 'europe', 'wolfgang', '’ s philosophy', 'democratic institutions', 'timely moment', 'dear friend', 'birthday flowers']
# Content 8: ['inflation', 'near term', 'energy prices reverse', 'government support measures', 'germany', 'gas price cap', 'vat', 'inflation target', 'sustainable basis', 'ukraine', 'gaza', 'global crises', 'central bank ’ s work', 'geopolitical', 'shocks lead', 'economic decisions', 'energy prices', 'world trade', 'chains –', 'red sea', 'geopolitics', 'green transition', 'solar cells', 'political ends', 'core business', 'your', 'policy rate decisions', 'historical data', 'global situation', 'historical', 'historical knowledge', 'macroeconomic environment', 'long phase', 'low inflation', 'russia', '’ s war', 'ukraine', 'new world', 'looking', 'low interest rates', 'great inflation', 'inflation', 'past decades', 'was', 'central banks ’', 'sound monetary policy', 'great inflation', 'monetary policy', 'central banks', 'clearer mandate', 'price stability', 'monetary policy', 'macroeconomic trends', 'china', '’ s entry', 'world market', 'important role', 'stable prices', 'severe external shocks', 'monetary policy', 'will', 'inflation target', 'supply-side shocks', 'climate', 'extreme', 'food prices', 'low water levels', 'panama', 'canal increase transportation costs', 'carbon taxes', 'partial withdrawal', 'artificial intelligence', 'productivity growth', 'temper inflation', 'executive board', 'fractious relationship', 'germans', 'ecb', 'germans', 'ecb', 'ecb', '’ s credibility', 'ecb', 'people haven ’ t forgotten', 'interest rates', 'short time', 'monetary policy', 'inflation', 'energy prices', 'determined', 'monetary policy', 'dampen demand', 'anchor inflation expectations', 'central bank', 'inflation', 'monetary policy', 'deep recession', 'old levels', 'massive consequences', 'monetary policy', 'energy price shock', 'energy imports poorer overall', 'somebody', '% inflation target', 'high level', 'target inflation', 'price level', 'inflation rates', 'sharp interest rate hikes', 'record profits', 'price stability mandate', 'bank profits', 'lent money', 'interest rates', 'banks ’ profits', 'credit default risks', 'short-term profits', 'future losses', 'erring', 'high profits', '% deposit facility rate', 'excess reserves', 'ecb', 'minimum reserve requirement', 'july', 'minimum reserves', 'minimum reserve requirement', 'minimum reserve base', 'customer deposits', 'minimum reserve requirement', 'effective way', 'excess liquidity', 'large', 'excess liquidity', 'minimum reserve requirements', 'large banks', 'deposit rate', 'low excess amounts', 'ecb', 'longer-term loans', 'negative interest', 'excess liquidity', 'large banks', 'monetary policy', 'ecb', 'sovereign bonds –', 'excess reserve problem', 'ecb', '’ s balance sheet', 'excess liquidity', 'monetary policy instrument', 'ecb', 'policy rates', 'balance sheet', 'market turbulence', 'ecb', 'central bank', 'losses doesn ’ t look', 'monetary policy considerations', 'pandemic emergency purchase programme', 'serious financial crisis', 'people ’ s', 'ecb', '’ s losses', 'central bank ’ s credibility', 'might lead', 'certain reassessment', 'ecb', '’ s bond', 'bond', 'distinct goals', 'price stability', 'market stabilisation', 'financial markets', 'effective bond', 'low inflation', 'fiscal policy', 'low interest rate period', 'monetary policy', 'monetary policy need', 'ecb', 'key interest rate', 'central banks', 'central bank needs', 'such situations']
# Content 9: ['wage', 'cost data', 'spain', 'ecb', 'christine lagarde', 'domestic inflation', 'wage moderation', 'indicators', 'clear downturn', 'energy components', 'negative impact', 'monetary policy', 'average wage growth', 'euro area', 'whereas productivity', 'unit labour costs', 'inflationary pressures', 'profit margins', 'labour costs', 'moderate inflation growth', 'ecb', 'analyse developments', 'wage costs', 'profit margins', '% target', 'eu', 'high private sector debt levels', 'significant impact', 'coronavirus pandemic', 'fiscal policy', 'monetary policy', 'european union', 'action plan', 'generation eu', 'income indicators', 'pre-pandemic levels', 'ecb', 'monetary policy', 'fiscal policy return', 'euro area inflation', 'november', 'euro area', 'gdp', 'interest rates', 'interest', 'monetary', 'interest rates', 'economic activity', 'economic activity', 'inflation slows', 'stable manner', 'monetary policy', '’ s', 'interest rate cuts', 'current interest rates', 'monetary policy', '’ s', 'interest rates', 'certain quarters', 'ecb', 'federal reserve', 'us economy ’ s fundamentals', 'cycles differ', 'europe', '’ s', 'fiscal policy', 'euro area', 'unemployment rate', 'labour market', 'good shape', 'different situations', 'central bank', 'world ’ s', 'federal reserve', 'ecb', '’ s', 'monetary decisions', 'monetary union', 'europe', 'european deposit insurance scheme', 'european elections', 'june', 'european commission ’ s agenda', 'fiscal union', 'common fiscal stabilisation function', 'ukraine', 'ecb', 'technical recession', 'consecutive quarters', 'negative growth', 'main issue', 'europe', '’ s economy', 'structural growth problem', 'european commission', 'moderate growth', 'potential growth levels', 'europe', 'global economies', 'energy crisis', 'competitiveness issues', 'structural', 'monetary policy', 'clear', 'capital markets union', 'european union', 'state aid', 'creates imbalances', 'fiscal position', 'europe', 'low growth potential', 'medium term', 'european union ’ s', 'generation', 'generation', 'positive aspects', 'joint debt', 'positive effects', 'monetary union', 'fiscal policy instrument', 'structural reforms', 'staying', 'european union', 'fiscal rules', 'ecb', 'markets', 'interest rates', 'sovereign debt', 'low growth', 'tight monetary policy', 'geopolitical risks', 'clear framework', 'common fiscal rules', 'reduces uncertainty', 'ecb', 'fiscal policy', 'bad times', 'good times', 'fiscal', 'action plans need', 'public debt-to-gdp ratio', 'structural deficits', 'fiscal space', 'public investment', 'structural reforms', 'eu', '“ austerity ”', 'fiscal', 'fiscal rules', 'countercyclical action', 'public deficit', 'economic downturn', 'countries need', 'fiscal positions', 'public deficit', 'fiscal policy', 'basic difference', 'financial crisis', 'different monetary policy response', 'pandemic asset purchase programme', 'immense support', 'european economy', 'european countries', 'banking', 'payments surplus', 'greece', 'portugal', 'significant budgetary adjustments', 'risk premia', 'ratings agencies', 'european countries', 'considerable efforts', 'public finances', 'medium term', 'eu', 'important projects', 'ecb', 'digital euro', 'key components', 'euro banknotes', 'digital euro', 'digital form', 'central bank', 'alternative means', 'digital euro', 'digital euro', 'current accounts', 'government ’ s optimism', 'spanish economy', 'spanish economy', 'external sector', 'international tourism', 'pre-pandemic levels', 'affects medium-', 'long-term growth', '% unemployment rate', 'labour market', 'euro area countries', 'spain', 'high public debt-to-gdp ratio', 'prudent adjustment programme', 'public debt', 'gdp', 'economic slowdown', 'geopolitical risks', 'new framework', 'fiscal rules', 'interest rates', 'economic policy', 'spanish context', 'nadia calviño', '’ s appointment', 'european investment bank', 'spaniard', 'spaniards', 'key positions', 'european union', 'calviño', 'domestic affairs', 'sure whoever']
# Content 10: ['november', 'inflation reading', 'does', 'recent string', 'downside surprises', 'inflation trajectory', '’ m', 'famous quote', 'john maynard keynes', 'past year headline inflation', 'side shocks', 'food prices', 'base', 'significant role', 'november', 'flash release', 'pleasant surprise', 'inflation developments', 'positive developments', '’ s', 'fiscal measures', '’ s', 'new price spike', 'disinflationary process', '% target', 'monetary policy', 'restrictive policy', 'aggregate demand', 'economic growth', '’ s', 'below-potential growth', 'inflation path', 'september', '’ s', 'december', 'staff projections', 'recent inflation print', 'main objective', 'september', 'hard data', 'soft data', 'managers ’ indices', 'pmis', '’ re', 'small uptick', 'foster confidence', 'large extent', 'labour market', 'labour force', 'economic growth', 'significant deterioration', 'labour market', 'growth recovery', 'time accelerate', 'disinflationary process', 'labour market', 'significant deterioration', 'rapid drop', 'credit demand', '’ re', 'monetary policy transmission', 'sharp increase', 'strong slowdown', 'loan growth', 'markets', 'early spring rate', 'ecb', 'steady rates', 'markets', 'large rate cuts', 'central banks', 'above-target inflation', 'previous communication', 'governing', 'council meeting', 'key policy rates need', '% target', 'sustainable manner', 'according', 'staff projections', 'current level', 'time frame', 'transmission', 'inflationary pressures', 'disinflationary process', '’ ve', 'strong wage growth', 'sharp increase', 'unit labour costs', 'services inflation', 'good indication', 'disinflationary process', '’ re', 'wage agreements', 'monetary policy decisions', 'current level', 'rate increases', 'recent inflation number', 'rate increase', 'steady rates', '’ s', 'downward movement', '’ s', 'unit profits', 'am', '’ re', '’ s', 'main thing', '’ s', 'months ’ time', 'pandemic emergency purchase programme', 'pepp', 'lagarde', 'governing', 'pepp', '’ ll', '’ s', '’ s', '’ re', 'pepp', '’ s', 'am', 'reinvestments end', 'outright sales', 'asset purchase programme', 'app', 'pepp', 'outright sales', 'march', 'demand-driven system', 'ecb', '’ s', 'new operational framework', 'demand-driven system', 'heterogeneous currency union', 'likely limits', 'central bank balance sheet', 'different ways', 'framework review', 'monetary policy', 'negative side', 'new system', 'euro area', 'financial system', 'legal framework', 'market footprint', 'abundant excess liquidity', 'money market rates', 'balance sheet', 'optimal size', 'various factors', '’ t project', 'main drivers', 'central bank balance sheet', 'autonomous factors – banknotes', 'official sector deposits –', 'reserve requirements', 'balance sheet', 'global financial crisis', 'excess liquidity', 'precautionary reasons', 'demand-driven system', 'balance sheet', 'banks ’ demand', 'excess liquidity', 'good thing', 'don ’ t', 'federal reserve', 'floor system', 'world ’ s', 'central banks', 'different frameworks', 'different frameworks', 'fed', 'supply-driven floor', 'england', 'demand-driven floor', 'sveriges riksbank', 'narrow corridor', 'central banks', 'classical corridor', 'wide variety', 'specific financial systems', 'structural portfolio', 'bonds and/or longer-term bank loans', 'portfolio need', '’ m', 'framework review', 'different ways', 'financial system', 'different tools', 'huge monetary policy bond portfolio', 'balance sheet', 'structural portfolio', 'march', 'structural portfolio', 'national central banks', 'agreement', 'financial assets', 'anfa', 'future ”', 'longer-term credit operations', 'structural portfolio', 'balance sheet', 'global financial crisis', 'balance sheet', 'ecb', 'new longer-term', 'different options', 'longer-term operations', 'tltros', 'market rates', 'banks ’ perspective', 'certain reliability', 'certain financial centres', 'minimum reserve requirements', 'colleagues advocate', 'minimum reserve requirements', 'july', 'minimum reserve requireme ...
# Content 11: ['please', 'english', 'dutch', 'english', 'version prevails', 'excessive profits', 'ecb', '’ s', 'financial stability review', 'bank profitability', 'interest rate margins', 'euro area banks', 'illusion −', 'short-term improvement', 'long term', 'default rates', 'asset quality', 'term accounts', 'interest rates', 'likewise', 'banks issue', 'putting', 'high bank profitability', 'financial markets', 'bank share valuations', 'high profits', 'interest rate risks', 'ecb', 'interest rate risk', 'european banks', '’ t', 'us banks', 'silicon', 'valley bank', 'different business model', 'interest rates', 'market rate', 'europe', 'interest rates', 'interest rate risk', 'time banks', 'interest rates', 'politicians', 'interest rates', 'good idea', 'ecb', 'raises interest rates', 'lending', 'savings accounts', 'interest rates', 'monetary policy transmission', 'interest rates', 'abundant liquidity', 'excess liquidity', 'interest rates', 'savings accounts', 'reality –', 'member states', 'interest rates', 'spain', 'euro', 'way mortgage loans', 'strengthening', 'policy rates', 'belgium', 'spanish situation', '’ s', 'own country', 'euro area averages', 'economists criticise', 'excess liquidity', 'ecb', 'generous profits', 'interest rates', '’ s', 'ecb', 'interest rates', 'remuneration categories', 'bank balance sheets', 'minimum reserve requirement', 'capital base', '’ s', 'good idea', 'banks ’ minimum reserves', 'central bank governors', 'minimum reserve requirement', 'banks ’ liabilities', 'monetary policy shouldn ’ t', 'financial position', 'central banks', 'national central banks', 'significant losses', 'sovereign bonds', 'losses pose', '’ s', 'central banks', 'interest rates', 'net outcome', 'central bank profits', 'real estate market', 'monetary policy', 'sharp rise', 'interest rates', 'real estate prices', 'price trends', 'house prices', 'commercial property prices', 'does', 'situation pose', 'real estate', 'residential real estate', 'commercial', 'real estate', 'mutual funds', 'financial system', 'high degree', 'overall picture', 'huge', 'buildings climate-proof', 'interest rates', 'climate transition', '’ s', 'substantial investments', 'european funds', 'generation eu', 'fiscal policy', 'doesn ’ t', 'ecb', 'monetary policy', 'monetary', 'climate transition', 'various wind farms', 'ecb', 'climate policy', '’ s', 'secondary objective', '’ s', 'national governments', 'climate policy', 'corporate bond portfolio', 'small contribution', 'clear signal', 'ecb', 'digital euro', 'physical euro', 'natural evolution', 'digital euro', 'central bank', 'digital euro', 'public money', 'digital euro', 'digital euro people', 'digital euro', '’ t', 'current accounts', 'clear message', 'digital euro', 'investment product', 'simple means', 'complement banknotes', 'won', '’ t', 'digital euro', 'ecb', 'preparation phase', 'cost-benefit analysis', 'alternative means', 'euro area', 'european strategic autonomy', 'preparation phase', 'european commission', 'european council', 'european union', 'european parliament', 'belgium', 'netherlands', '’ s', 'actual inflation', 'ecb', '’ s', 'energy prices', 'inflation rate', 'eurostat', 'ecb', 'changes aim', 'inflation measurement', 'statistical', 'harmonised index', 'prices', 'hicp', 'methodological changes', 'house prices', 'inflation rate', 'monetary policy', 'strategic review', 'share information', 'eurostat', 'hicp', 'energy prices', 'statistical choice', 'country ’ s price index', 'europe', 'russian assets', 'euroclear', 'ukraine', 'ecb', 'ecb', 'ukraine', 'frozen assets', 'global decision', 'g7', 'reputational damage', 'safe currency', 'important currency', 'long-term reputation', 'ukraine', 'belgium', 'ethical bank', 'newb', 'new banks', 'particular case', 'different procedures', 'capital requirements', 'new retail bank', 'haven ’ t', 'new banks', 'years ...', 'euro area', 'real question', 'banks ’', 'traditional business model', 'new sources', 'revenue need', 'profitability doesn ’ t meet', 'cross-b ...
# Content 12: ['ecb', 'key interest rates', 'october', 'consecutive interest rate increases', 'percentage points', 'july', 'eurostat', 'euro area headline inflation', 'october', 'does', 'interest rate hikes', 'interest rates', 'current level', '% level', 'price stability', 'positive overall', 'core inflation', 'data-dependent approach', 'interest rate decisions', 'euro', 'gdp', 'positive base effect', 'commodity price shock', 'ecb', 'prioritise growth', 'primary task', 'price stability', 'central banks', 'ecb', 'dual mandate', 'economic variables', 'recent projections', 'downside risks', 'september', 'euro area inflation', 'interest rates', 'current levels', 'ecb', 'new forecasts', 'december', 'will', 'september', 'downward revisions', 'growth outlook', 'regards inflation', 'september', 'data-dependent approach', 'october', 'ecb', 'key interest rates', 'substantial contribution', 'potential lags', 'monetary policy', 'recent', 'headline inflation figures', 'sticky core inflation', 'monetary policy statement', 'concrete period', 'high level', 'geopolitical risks', 'ukraine', 'ecb', 'interest rates', 'restrictive levels', 'things evolve month', 'interest rates', 'interest rates', 'ecb', '’ s', 'monetary policy', 'euro area average', 'member', 'significant differences', 'according', 'eurostat', 'october slovakia', 'inflation rate', 'slovenia', 'netherlands', 'belgium', 'euro area countries', 'financial structures', 'ukraine', 'ecb', 'monetary policy', 'euro area countries', 'price stability', 'euro area', 'fiscal policies', 'support measures', 'energy crisis', 'fiscal', 'key element', 'inflation rates', 'monetary policy', 'ecb', 'central banks', 'core inflation', 'excludes energy', 'food prices', 'ecb', '’ s', 'ecb', 'christine lagarde', 'profit margins', 'domestic inflation', 'wage increases', 'core inflation', 'energy shock', 'core inflation', 'euro exchange rate', 'nonetheless plays', 'unit labour costs', 'rising', 'labour costs result', 'wage developments', 'wage growth', 'euro area', 'employment growth', 'output growth', 'profit margins', 'unit labour costs', 'profit margins', 'labour costs', 'labour costs', 'profit margins', 'final prices', 'ecb', 'artificial intelligence', 'financial system', 'real economy', 'monumental amount', 'financial system', 'ecb', 'demand side', 'supply-side factors', 'geopolitical tensions', 'demographic picture', 'deal', 'monetary policy', 'monetary policy', 'interest rate increases', 'monetary policy decisions', 'aggregate demand', 'monetary policy', 'decisions aim', 'aggregate demand', 'monetary', 'supply-side issues', 'structural policies', 'fiscal policies', '’ s', '’ s', 'possible price-wage-profit spiral', 'inflation expectations', 'monetary policy stance', 'ecb', 'eurostat', 'ecb', '’ s strategy review', 'costs need', 'such costs need', 'eurostat', '’ s responsibility', 'including', 'measurement –', 'property cost – contributes', 'eurostat', 'eu', 'euro area', 'ecb', 'record-high euro area inflation', 'interest rates', 'record pace', 'slovenia', 'subsequent lack', 'key interest rates', 'current situation', 'excess liquidity', 'banks haven ’ t', 'liquidity conditions', 'european banks –', 'long-term liquidity', 'slow-but-steady increase', 'time deposits', '’ ll', 'interest rates', 'monetary policy', 'deposit interest rates', 'considerable growth', 'banks ’ net interest income', 'short-term goals', 'sustainable business goals', 'ecb', 'excess liquidity', '’ re', 'european banks', 'key interest rates', 'profit margins', 'market valuation', 'banks ’ revenues', '’ s', 'financial stability', 'euro area', 'economic slowdown', 'insolvency proceedings', 'real estate market', 'germany', 'residential property prices', 'ecb', '’ s', 'monetary policy', 'interest rates', 'financial stability situation changes', 'financial assets', 'real estate assets', 'main risks', 'financial stability', 'euro area', 'asset prices', 'good position', 'financial stability', 'financial intermediaries', 'real estate', 'mutual ...
# Content 13: ['athens', 'greece', '’ s resilience', 'phenomenal recovery capacity', 'greece', 'success story', 'key performance indicators', 'greece', '’ s', 'financial situation', 'fiscal situation', 'debt-to-gdp ratio', 'greece', 'to-do list', 'country ’ s efforts', 'recent decisions', 'greece', '’ s', 'investment grade', '’ s', 'tremendous testament', 'country ’ s efforts', 'fiscal adjustments', 'resolute efforts', 'greek people', 'greek authorities', 'high debt-to-gdp ratio', 'debt-to-gdp ratio', 'downward trend needs', 'greece', 'grexit', 'particular moments', 'g20', 'november', 'possible referendum', 'didn ’ t', 'july', 'grexit', 'hadn ’ t', 'european leaders', 'front-row seat', 'greek financial crisis', 'original mistake', 'fiscal discipline', 'prudent principle', 'rainy-day fund', 'bad times', 'fiscal policies', 'original mistakes', 'imf', 'deep changes', 'fiscal consolidation', 'weren ’ t', 'monetary union', 'fiscal union', 'greece', '’ s', 'specific fiscal situation', 'pertinent lesson', 'collective discipline', 'fiscal union', 'pressing concern', 'monetary union', 'fiscal union', 'clear fiscal guardrails', 'fiscal framework', 'fiscal policies', 'monetary union', 'greek situation', 'subsequent political team', 'didn ’ t', 'financial sector', 'current state', 'significant sign', 'capital', 'liquidity ratios', 'greek banks', 'large foreign bank', 'greek bank', 'clear indication', 'greece yannis stournaras', 'syntagma', 'greece', 'frequent contact', 'imf', 'mission ’ s', 'special security measures', 'greeks', 'eu', '’ s', 'greece', 'economic events', 'monetary policy', 'multiple geopolitical developments', 'various corners', 'major schism', 'bipolar power structure', 'anticipate things', 'future developments', '’ s', 'crises', 'various parts', '’ s', 'final outcome', 'current crisis', 'serious challenge', '’ s', '’ s', '’ s', 'traditional way', 'according', 'food prices', 'political implications', 'political pressures', 'measure inflation', 'headline rate', 'europe', 'variable components', '’ s', 'droughts', 'sea levels', 'food prices', 'political implications', 'ensure price stability', 'social peace', '’ d', '’ s', '’ m', 'fall asleep', 'foremost terrible', 'people – terrible', 'people ’ s confidence']
# Content 14: ['ecb', 'interest rates', 'federal reserve', 'us inflation', 'monetary policy', 'ecb', 'interest rates', 'fed', 'boe', 'rate increases', 'central banks', 'pandemic cuts', 'qe', 'large-scale asset puchases', 'ed', 'december', 'qe', 'july', 'march', 'don ’ t', 'interest rate', 'good understanding', 'energy shock', 'central bank', 'timely manner', 'ecb', 'energy prices rise', 'deep recession', 'september', 'energy price increases', 'consumer prices', 'history', 'demand conditions', 'current interest rate', '’ s', 'fixed-rate mortgages', 'interest rate', 'interest rates', 'interest rates', 'trade unions', '’ ve', 'labour market', 'collective', 'wage agreements', 'high inflation', 'wage growth', 'economic environment', 'monetary policy', 'pretty stagnant', 'germany', 'inflation rates', 'europe', 'growth rates', 'ecb', '’ s', 'good policies', 'national level', 'national policies', 'interest rate', 'qe', 'balance sheet', 'large-scale', 'bond sales', 'interest rates', 'aren', '’ t', 'own balance sheet', 'app', 'balance sheet', 'pepp', 'bond markets', 'qe', 'interest rate', 'european governments', 'compared', 'interest rates', 'balance sheet', 'secondary importance', 'effective way', 'interest rate', 'bond markets', 'ecb', 'interest rates', 'european governments', 'interest rate', 'long-term bonds', 'peak policy rate', 'interest rates', 'neutral range', 'interest rates', 'inflation shocks', 'normalise policy', 'wage settlements', 'countries release', '’ s', 'high degree', 'interest rates', 'high wage increases', 'price increases', '’ re', 'neutral ” level', 'pandemic inflation', 'interest rates', 'neutral rates', 'interest rates', 'neutral range', 'pre-pandemic levels', 'market prices', 'interest rates', 'reasonable guess', 'long-term average', 'policy rates', "wo n't stay", '’ t envisage', 'major recession', 'ecb', '’ s', 'chief economist', 'inflation spike', 'does', 'governing', 'natural question', 'economic profession', 'eurosystem', 'whole range', 'chief economist', 'personal duty', 'eurosystem', 'important task', 'monetary policy', 'timely manner', 'driver ’ s seat', 'ecb', '’ s', 'global situation', 'inflation', 'significant policy', 'press conference', 'press conference', 'broad consensus', 'governing']
# Content 15: ['ecb', 'key interest rates', 'consecutive time', 'deposit facility', 'coming', 'interest rates', 'european central bank', '“ permacrisis ”', 'constant succession', 'unprecedented crises −', 'health crisis', 'russia', '’ s', 'ukraine', 'energy crisis', 'eu', 'interest rate-sensitive sectors', 'real estate', 'ecb', '’ s mandate', 'price stability', '’ s', 'ecb', 'interest rates', 'substantial contribution', 'timely return', 'complete shutdown', 'health crisis', 'europe', 'energy crisis', 'sudden rise', 'macroeconomic models', 'central banks', 'growth projections', 'have', 'past projection errors', 'ecb', '’ s actions', 'close', 'euro area citizens', '% trust', 'ecb', 'health crisis', 'effective methods', 'counter fake news', 'economic world', 'ecb', 'central bank', 'sharp rise', 'energy prices', 'economies –', 'exceptional rise', 'china', 'inflation rate', 'october', 'current level', 'energy prices', '’ s', 'general feeling', 'europe…', '’ s', 'inflation', '’ s', 'good news', 'economic policies', 'europe', 'monetary', 'growth projections worldwide', 'europe', 'potential', 'europe', 'euro area', 'percentage point', '’ s', '’ t', 'euro area comprises', 'different countries', 'different fiscal policies', 'different treasuries', 'international reference currency', 'us economy', 'europe', 'europe', 'growth projections', 'potential growth', 'euro area', 'europe', 'unprecedented defensive measures', 'generation eu', 'structural', 'gas reserves', 'september', 'german economy', 'euro area', 'european growth', 'germany', 'economic model', 'cheap energy supplies', 'china', 'german economy', 'growth outlook', 'does', 'ecb', '’ s mission', 'ecb', 'price stability', 'economic actors', 'entire euro area', 'measure average inflation', 'euro area', 'inflation –', 'france', 'persistent inflation affects people ’ s', 'france', 'european average', 'long time', 'europe', 'interest rates', 'ecb', 'france', 'euro area countries', 'effective tool', 'ensure price stability', 'doesn', '’ t', 'price stability', 'interest rates', 'economic activity', 'dampens demand', 'dangerous inflationary spiral', 'wage-price spiral', 'aren ’ t', 'wage', 'euro area', 'inflation rates', 'france', 'germany', 'collateral damage', 'monetary policy', 'ecb', 'key interest rates', 'price stability mandate', 'interest rates', 'authorities need', 'major risk', 'adequate means', 'repayment deadlines', 'ecb', 'economic outlook', 'growth figures', 'inflation', 'employment rate', '’ s', 'europe', '’ s', 'big question', 'will', 'salary increases', 'margins –', 'didn ’ t', 'key question', 'economic projections', 'previous crises', 'salary increases', '’ s', 'public opinion', 'public authorities', 'energy prices', 'oil prices', 'energy mix', 'foreign suppliers', 'anxiety', 'european society', 'combating', 'imperative –', 'message home', 'everyone', '’ s', 'energy transition', '’ s support', 'distributive policies', 'don ’ t worsen inequality', 'energy transition', 'social means', 'collective approach', 'europeans', '’ s', 'current version', 'stability', 'growth pact', 'heads', 'fiscal framework', 'fiscal policies']
# Content 16: ['ecb', "'s perspective", 'new [', 'september', 'inflation ] data', 'inflation growth', 'overall', 'recent news', 'headline', 'euro area', 'october', 'large part', 'previous shocks', 'food price inflation', 'statistical effects', 'so-called base', 'large price increases', 'core inflation', 'excludes energy', 'euro area', 'headline inflation', 'september', 'inflation expectations', 'kilometre ”', 'oil price increase', 'recent months', 'recent rise', 'oil prices', 'side shocks', 'food prices', '’ ve', 'frequent extreme weather events', 'food prices', 'upside pressure', 'broad expectations', 'financial markets', 'central banks', 'interest rate hikes', '’ s', 'ecb', 'policy rates', 'restrictive levels', 'substantial contribution', 'timely return', 'long rates', 'restrictive levels', 'inflation outlook', 'monetary policy transmission', 'currently', 'right direction', 'upside risks', 'side shocks', 'productivity growth', 'profit margins', 'such risks need', 'interest rate hikes', 'major differences', 'inflation rates', 'negative numbers', 'netherlands', 'slovakia', 'monetary policy', 'primary mandate', 'price stability', 'euro area', 'monetary policy decisions', 'account information', 'member', 'specific developments', 'particular country', 'such developments', 'national policies', 'structural policies', 'unusual heterogeneity', 'inflation rates', 'food inflation', 'large role', 'russian', 'energy inflation', 'energy price shock', 'inflation rates', 'different fiscal implications', 'energy prices fall', 'others need', 'institutional characteristics', 'energy markets differ', 'member', 'wholesale energy prices', 'retail prices', 'energy prices rise', 'fixed-price contracts', 'long duration', 'croatia', 'food prices', 'large share', 'consumption basket', 'heterogeneity complicates', 'monetary policy', 'euro area', 'croatia', 'introduce price', 'certain basic consumer items', 'bad sides', 'inflationary pressures', 'measures', 'control prices', 'price caps', 'short run', 'smooth inflation', 'such measures', 'fiscal budget', 'vulnerable groups', 'supply capacity', 'control prices', 'short run', 'short run', 'positive effect', 'current inflation', 'inflation expectations', 'current developments', 'negative effects', 'croatia', 'inflation rates', 'euro area', 'ample excess liquidity', 'croatia', 'euro area', 'banks ’', 'minimum reserve requirements', 'ecb', 'interest rates', 'monetary policy transmission', 'member', 'monetary policy', 'currency union', 'excess liquidity', 'euro area level', 'country level', 'excess', 'euro area', 'monetary policy transmission', 'key policy rate', 'deposit facility rate', 'money market', 'measurable increase', 'monetary policy transmission', 'member', 'crucial factor', 'variable versus fixed-rate loans', 'variable interest rate', 'croatia', 'special case', 'minimum reserve requirements', 'excess liquidity', 'strong loan growth', 'croatia', 'strong economic performance', 'croatian', 'national bank', 'countercyclical capital buffer', 'excessive loan growth', 'currency union', 'macroprudential tools', 'national level', 'national central bank ’ s domain', 'macroprudential tools', 'european level –', 'croatia', '’ s case', 'central bank –', 'specific situation', 'main contributor', 'economic growth', 'credit activity', 'croatia', 'croatia', '’ s economy', 'attractive place', 'summer holidays', 'euro area', 'croatia', 'general public', 'current circumstances', 'high income', 'central banks', 'high volume', 'excess liquidity', 'previous monetary policy actions', 'excess', 'deposit facility rate', 'interest rate', 'balance sheet', 'balance sheet', 'short-term money market rates', 'policy rate', 'monetary policy stance', 'raising', 'interest rates', 'rates', 'time deposits', 'sight deposits', 'alternative investments', 'interest rates', 'market mechanism', 'forces banks', 'deposit rates', 'banks ’', 'short run', 'longer-term consequences', 'interest rates', 'bank profitability', 'interest income', 'bank  ...
# Content 17: ['’ s', 'ecb', 'consecutive time', 'tame inflation', 'important part', 'monetary policy', 'different legs', 'monetary policy decisions', 'financial markets', 'significant drop', 'real economy', 'economic activity', 'households ’', 'disposable income', 'global economy', 'key point', 'future decisions', 'monetary policy', 'real economy', 'present level', 'interest rates', 'price stability', 'monetary policy', 'painful recession', 'painful recession', 'price stability', 'delicate balance', 'inflation converges', 'does', 'recent rise', 'gas prices', 'game changer', 'oil price', 'detrimental impact', 'inflation expectations', 'ecb', 'well', 'steady way', 'price stability', 'sustainable way', 'rate cuts', '’ s', '’ s', 'base', 'supply side bottlenecks', 'monetary policy', 'clear slowdown', 'euro area', '’ s', '’ s', 'oil prices', 'wages', 'demand', 'clear slowdown', 'disinflation process', 'big deficits', 'fiscal policy', '’ s', 'fiscal stance', 'eu', 'fiscal rules', '” approach', 'fiscal policy', 'monetary policy', 'fiscal policy', 'bad policy mix', 'fiscal deficit', 'does', 'ecb', 'excess liquidity', 'monetary policy', 'correct pace', 'correct path', 'tltro', '€2.1 trillion', 'pandemic emergency purchase programme', 'governing', 'pepp', 'formal structure', 'pepp', 'financial market fragmentation', 'extra lines', 'pepp', 'address fragmentation', 'pepp', '€2 trillion', 'full run-off', '’ ll', 'return', 'european banks ’ equity', 'net interest margins', 'interest rates', 'banks ’ valuations', 'main reason', 'european banks', '’ s', 'interest rates increase', 'markets', 'economic slowdown', 'loans levels', 'current figures', '’ s', 'bank profits', 'introduce bank taxes', 'bank taxes', 'italy', 'final proposal', 'european banks', 'dividend payments', 'share buybacks', 'governing', 'minimum reserve requirements', 'monetary policy', 'price stability', 'national central banks', 'price stability', 'windfall profits', 'commercial banks', 'interest rates', 'property sector', 'commercial property', 'important decline', 'nordic', 'main problems', 'sweden', 'finland', 'nordic', '’ s', 'residential real estate', 'germany', 'total surprise', 'recent data', 'house prices', '’ s', 'clear indication', 'mutual funds', 'big exposure', 'real estate', 'commercial property –', 'residential property –', 'main source', 'financial stability']
# Content 18: ['your', 'terschelling', 'central banker', 'certain pessimism', 'isn ’ t', 'sufficient buy-in', 'polluters ”', 'looking', 'zero-emission economy', 'right direction', 'main message', 'recent economy-wide climate stress test', 'frankfurt', 'ecb', 'multi-year strategy', 'environmental risks', 'conduct self-assessments', 'progress – banks', 'environmental risks', 'initial assessments', 'interim deadlines', 'march', 'banks need', 'expectations –', 'environmental risks', 'financial risks', 'ambitious supervisors', 'real step', 'basel', 'banking supervision', '’ ve', '’ s', 'gradualist approach', 'don ’ t', 'consequences ”', 'don ’ t', 'gradual –', 'clear deadlines −', 'interim deadlines −', 'periodic penalty payments', '’ s', 'supervisory expectations', 'well', '’ s', '’ re', '’ s', '’ t', 'risks don ’ t', 'materialise –', 'real progress', 'patchy', 'patchy', 'climate models', 'don ’ t', 'things banks', 'besides climate', 'numerous options', 'ecb', 'green investment', 'might', 'tltros', 'whereas', '’ ve', 'monetary policy', 'possible future instruments', 'particular moment', 'instrument needs', 'primary mandate', 'price stability', 'environment –', 'climate considerations', 'monetary policy strategy', '’ s', 'climate considerations', 'future −', 'purchase programme', 'national governments subsidise fossil fuel industries', 'obviously', 'ecb', '’ s mandate', 'issue constitutes', 'financial stability risk', 'ecb', 'private citizens', '’ re', 'exponential growth', 'banks need', 'certain cases', 'far-reaching legal theories', 'antagonism –', 'energy transition', 'climate crisis', 'eu member', 'paris agreement-aligned', 'suboptimal situation', 'transition ends', 'own analysis', 'bringing', 'monetary policy –', 'governing', 'council meeting', 'ecb', 'interest rates', 'final time', '’ ve', 'current assessment', 'current interest rate levels', 'substantial contribution', 'inflation target', 'medium term', 'does', 'policy rates', '’ s', 'decisions meeting', 'data-dependent basis', 'making', 'inflation outlook', 'ecb', 'price pressures', '’ s', 'energy prices –', 'july', 'monetary policy statement', 'climate conditions', 'climate', 'longer-term inflation dynamics', 'granular analysis', 'transition risks', 'helpful', 'ecb', '’ s executive board', 'isabel schnabel', 'green transition', 'inflationary –', '’ s summer heatwave', 'food inflation', '’ s', 'current interest rate environment', 'negative effect', 'green investment', 'interest rate decision', 'price stability mandate', 'stable environment', 'transition –', 'growth outlook', 'euro area', 'primary mandate', 'price stability', '’ re', 'sluggish growth', 'various explanatory factors', 'euro area exports', 'business investment', 'services sector', 'labour markets', 'disposable income', 'gdp', '’ s', 'primary mandate', 'price stability', 'rate hikes', '’ ve', 'july', '’ ve', 'recent assessments', 'inflation outlook', 'medium-term projections', 'equally', 'reinvestments need', 'based', '’ s assessments', 'substantial contribution', 'timely return', 'restrictive levels']
# Content 19: ['tenth time', 'inflation', 'well', 'low fives', 'august', 'low threes', 'intense inflation pressure', 'strong gas price increases', 'august', 'cent inflation rate', 'cent interest rate', 'inflation challenge', 'cent target', 'current levels', 'rate hikes', 'euro area', 'monetary policy', 'credit', 'strong credit growth', 'monetary policy', 'price increases', 'cost increases', 'point-in-time assessment', 'central banks', 'high uncertainty', 'cent rate', 'sure inflation', 'point-in-time conditional message', 'york', 'data points', 'high confidence', 'base case', 'interest rates', 'well', 'central banks', 'good idea', "'s unhelpful", 'central bank', 'inflation assessment', 'net signals', 'process issue', 'sufficient deterioration', 'good idea', 'calendar guidance', 'big issues', 'european case', 'wage negotiations', 'wage settlements', 'january', 'february', "'s kind", 'institutional settings', 'year reset', 'key elements', 'complete kind', 'important dimension', 'new year', 'monetary policy', 'market watchers', 'eurozone economy', 'ecb', 'energy shock', "people 's incomes", 'investment side', 'big adjustment', 'adjustment concludes', 'overall environment', 'good shape', 'household balance sheets', 'toxic mix', 'deep recession', 'special situation', 'european economy', 'unusual disinflation episode', 'europe', 'ukraine', 'energy prices', 'saudi arabia', 'russia', 'brent', 'core inflation', 'important factor', 'will', 'energy costs trigger', 'new round', 'price increases', 'services sector', 'restrictive interest rates', 'demand conditions', 'high energy costs', 'market share', '% interest rates –it', 'energy shock', 'food shock', 'food prices', 'core inflation', 'interest rate', 'interest rates', 'amplification effect']
# Content 20: ['’ s dive', 'broad inflation outlook', '’ re', 'august', 'flash data', 'august', 'core inflation', 'goods inflation', 'services inflation', 'strong price increases', 'famous core inflation', 'big components', 'energy', 'spectacular decline', 'oil markets', 'recent weeks', 'data show', 'cent overall', 'goods inflation', 'services inflation', 'welcome development', 'key trends', 'month ’ s reading', 'inflation data don ’ t', 'strong services inflation', 'strong demand', 'countries — services inflation', 'gas markets', 'major source', 'gas markets', 'downward drift', 'energy inflation', 'based', 'flash estimate', 'long-term inflation forecasts', 'obvious mandate', 'inflation target', 'september', 'june', 'basic narrative', 'inflation', 'essentially', 'basic shape', '’ s', 'multi-year process', 'cent inflation doesn ’ t collapse', 'significant drop', '’ s', 'cent inflation', 'clear connection', '’ s', '’ s', 'multi-year process', 'significant wage increases', 'june', 'overall wage adjustment', '’ ve', 'average wages', 'euro area', 'historical trends', 'september', '’ ll', 'target rate', 'policy challenge', 'whole challenge', '’ s', 'timely manner', 'timely manner', '’ s', 'current inflation episode', '’ s', 'longer-term behaviour', 'temporary inflation episode', '’ s', 'high inflation', '’ ve', 'longer-term projection', 'sellers ’ inflation', 'isabella weber', 'umass amherst', 'course –', '’ s', 'strategic price', 'others advocate', 'vital sectors', 'emergency response', 'local shocks', 'proximate mechanism', 'prices rise', 'cost base', 'energy prices', 'europe', '’ d', 'energy costs', '’ s', 'service industries –', 'restaurant ...', 'core measure', 'cost element', '’ s', '’ s', 'cost rises', '’ t', 'strategic element', 'cost increase', 'market conditions', 'extra profits', 'unique period', 'energy sector', '’ s', 'marginal source', 'essentially', '’ s', 'utility firms', 'lower-cost inputs', 'marginal price', 'significant profits', 'global forces', 'global forces', 'different economic environment', 'domestic firms', 'national economy', 'european economy', 'march', 'european economy', 'bank accounts', 'perfect environment', 'strategic price increases', 'going', '’ s', 'significant contribution', 'strategic pricing', 'profit component', 'price increases', 'don ’ t', '’ s', '’ s', '’ s', 'monetary policy', 'essentially', 'interest rate policy', 'firms', '’ s', 'nixon', '’ s', 'distinct debate –', '’ s distinct –', 'france', 'various forms', 'fiscal intervention', 'inflation increase', '’ s', 'interesting issue', 'such –', '’ d', 'sceptical camp', '’ s', 'people recognise', 'market power', 'monopoly power', 'market power interact', 'unusual environment', 'don ’ t', '’ d', '’ ve', 'interest rate hikes', '’ s', '’ re', 'dampen demand', 'irish homeowners', 'interest rates', 'war –', 'interest rate hikes', 'monetary policy', 'basic pattern', 'supply shocks', 'monetary policy', 'monetary policy', '’ s', 'number', 'basic task', 'inflation problem', 'high inflation rate –', 'time –', 'interest rate', 'pro-inflationary incentives', 'basically', 'on. ”', '’ s', '’ s', 'asset market', 'goods market', 'pro-inflationary behaviour', '’ s', 'interest rates', '’ s', 'basic reason', 'interest rates', 'restrictive territory', 'percentage points', 'interest rates', 'multi-year basis', 'number', 'wage increases', '’ ve', 'long amount', 'time –', 'famous phrase', '“ tit-for-tat ” inflation', 'original shock', 'interest rates means', 'price increases', 'euro area', 'capital-intensive sectors', 'tech sector', 'tech sector', 'ireland', 'start-up activity', 'fund activity', 'interest rates', 'interest rate policy', 'industry sectors', 'wouldn ’ t overemphasise', 'european context', 'mortgage channel', 'visible channel', 'high interest rates', 'overall mechanism', '’ re', 'vague representations', 'ecb', 'ecb', 'eventual outturn', 'was', 'was', 'labour market', 'wage growth', 'ecb', 'basic description', 'macro models', 'normal business cycles', 'a ...

# %% [markdown]
# 3. Topic Modeling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

def topic_modeling(df, n_topics=5, n_words=10):
    vec = CountVectorizer(stop_words='english')
    X = vec.fit_transform(df['contents'])
    lda = LatentDirichletAllocation(n_components=n_topics, random_state=0)
    lda.fit(X)
    feature_names = vec.get_feature_names_out()
    # Getting the top words for each topic
    top_words = []
    for topic_idx, topic in enumerate(lda.components_):
        top_features_ind = topic.argsort()[:-n_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        top_words.append(top_features)
    return lda, vec, top_words

# Apply the function
lda_model, vectorizer, top_words = topic_modeling(df)

# Now let's plot the top words per topic
def plot_top_words(top_words, n_topics=5):
    fig, axes = plt.subplots(1, n_topics, figsize=(15, 5), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic_words in enumerate(top_words):
        ax = axes[topic_idx]
        ax.barh(topic_words, range(len(topic_words)), color='blue', alpha=0.7)
        ax.set_title(f'Topic {topic_idx + 1}')
        ax.set_yticks(range(len(topic_words)))
        ax.set_yticklabels(topic_words)
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=10)
    plt.tight_layout()
    plt.show()

plot_top_words(top_words)

# %% [markdown]
# 4. Text Length Distribution

# %%
import matplotlib.pyplot as plt

def text_length_distribution(df):
    # Add a new column 'text_length' to the DataFrame based on the length of each entry in 'contents'
    df['text_length'] = df['contents'].apply(len)
    # Create a histogram of the text lengths
    plt.figure(dpi=300)  # Set the dpi for the entire figure
    # Define a color
    # Plot histogram with a label for the legend
    df['text_length'].hist(bins=30, color=color, label='Text Length')
    # Add title and labels
    plt.title('Distribution of Text Lengths')
    plt.xlabel('Text Length')
    plt.ylabel('Frequency')

    # Show the plot
    plt.show()

# Apply the function with an example DataFrame
# df = pd.DataFrame(...)  # Define or load your DataFrame here before using the function
text_length_distribution(df)
# Out:
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/2573972944.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_length'] = df['contents'].apply(len)

# %%
# average text length
df['text_length'].mean()
# Out:
# 9888.339869281046

# %% [markdown]
# 5. Readability Scores

# %%
import textstat

# %%
def readability_scores(df):
    df['readability'] = df['contents'].apply(textstat.flesch_reading_ease)
    return df

# Apply the function
df = readability_scores(df)
# Out:
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_884/3567504131.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['readability'] = df['contents'].apply(textstat.flesch_reading_ease)

# %%
# Plotting the readability scores
plt.figure(figsize=(10, 6), dpi=300)
plt.hist(df['readability'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Flesch Reading Ease Scores')
plt.xlabel('Readability Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# Interpretation:
#
# The histogram of Flesch Reading Ease Scores you’ve provided shows the distribution of readability scores for your ECB interview transcripts dataset. The Flesch Reading Ease Score is a measure of how easy a text is to read. The scale runs from 0 to 100, with higher scores indicating material that is easier to read. Here’s a general guide for interpreting the scores:
#
# + 90-100: Very Easy (easily understood by an average 11-year-old student)
# + 80-90: Easy
# + 70-80: Fairly Easy
# + 60-70: Standard (easily understood by 13- to 15-year-old students)
# + 50-60: Fairly Difficult
# + 30-50: Difficult (best understood by university graduates)
# + 0-30: Very Confusing

# %% [markdown]
# 6. Named Entity Recognition (NER)

# %%
"""import spacy

nlp = spacy.load('en_core_web_sm')

def named_entity_recognition(df):
    df['named_entities'] = df['contents'].apply(lambda x: [(ent.text, ent.label_) for ent in nlp(x).ents])
    return df

# Apply the function
df = named_entity_recognition(df)
"""
# Out:
# "import spacy\n\nnlp = spacy.load('en_core_web_sm')\n\ndef named_entity_recognition(df):\n    df['named_entities'] = df['contents'].apply(lambda x: [(ent.text, ent.label_) for ent in nlp(x).ents])\n    return df\n\n# Apply the function\ndf = named_entity_recognition(df)\n"

# %%
"""import pandas as pd
import matplotlib.pyplot as plt
import spacy
from collections import Counter

# Extract all entity labels
all_labels = [label for sublist in df['named_entities'] for _, label in sublist]

# Count frequency of each label
label_freq = Counter(all_labels)

# Data for plotting
labels, freqs = zip(*label_freq.items())

# Plotting
plt.figure(figsize=(10, 6), dpi=300)
plt.bar(labels, freqs, color='teal')
plt.title('Frequency of Named Entity Types')
plt.xlabel('Entity Types')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()
"""
# Out:
# "import pandas as pd\nimport matplotlib.pyplot as plt\nimport spacy\nfrom collections import Counter\n\n# Extract all entity labels\nall_labels = [label for sublist in df['named_entities'] for _, label in sublist]\n\n# Count frequency of each label\nlabel_freq = Counter(all_labels)\n\n# Data for plotting\nlabels, freqs = zip(*label_freq.items())\n\n# Plotting\nplt.figure(figsize=(10, 6), dpi=300)\nplt.bar(labels, freqs, color='teal')\nplt.title('Frequency of Named Entity Types')\nplt.xlabel('Entity Types')\nplt.ylabel('Frequency')\nplt.xticks(rotation=45)\nplt.show()\n"

# %% [markdown]
# The bar chart displaying the "Frequency of Named Entity Types" from your ECB interview transcripts provides insights into the kind of entities frequently mentioned in the discussions about inflation. Here's a breakdown of what each of these named entity types usually represents:
#
# + DATE: Refers to specific dates. The high frequency indicates many discussions about specific times, such as past events, deadlines, forecasts, or timeframes for economic policies.
# + ORDINAL: Represents "first", "second", "third", etc., which could be used to reference sequences or rankings, possibly related to economic indices or position statements.
# + ORG: Short for "organization", which could include banks, financial institutions, governments, and other bodies that are relevant to economic discussions.
# + PERCENT: Clearly essential in discussions of inflation, interest rates, and economic growth, where percentages are commonly used to express rates of change or proportions.
# + QUANTITY: This could refer to amounts of money, quantities in economic forecasts, or other numerical data.
# + CARDINAL: These are numbers that do not fall under another category and could refer to quantities, like fiscal numbers, statistical data, etc.
# + LOC: Short for "location", which could point to the mention of specific places important in the context of economic discussions, such as countries or regions experiencing different inflation rates.
# + GPE: Stands for "Geopolitical Entity", which would include countries, cities, states, etc., suggesting discussions may have involved comparisons of economic conditions across different regions.
# + NORP: Refers to nationalities or religious or political groups. This could indicate discussions around how different population groups are affected by or are responding to inflation.
# + PERSON: Implies that individuals are often referenced, which could be interviewees, economists, politicians, or key figures in finance and economics.
# + LAW: Points to legal or regulatory terms, which might come up in discussions of monetary policy, fiscal regulations, or legal frameworks affecting economic policy.
# + EVENT: Could involve specific events that have economic implications, such as policy announcements, market changes, or economic summits.

# %% [markdown]
# 7. Co-occurrence of Key Terms

# %%
import pandas as pd
from collections import defaultdict

# Define key terms you are interested in
key_terms = ['inflation', 'policy', 'economy', 'rates', 'ECB']

def co_occurrence_matrix(df, key_terms):
    # Create a dictionary to hold pairs of key terms and their co-occurrence count
    co_occurrence = defaultdict(int)
    
    # Process each document
    for document in df['contents']:
        words = document.lower().split()
        # Find which key terms are in the current document
        terms_in_doc = set(term for term in key_terms if term in words)
        # Increment counts for each pair of terms found in the same document
        for term1 in terms_in_doc:
            for term2 in terms_in_doc:
                if term1 != term2:
                    co_occurrence[(term1, term2)] += 1
    
    # Turn the co_occurrence dictionary into a DataFrame for better readability
    return pd.DataFrame(list(co_occurrence.items()), columns=['Term Pair', 'Co-occurrence'])

# Apply the function
co_occurrence_df = co_occurrence_matrix(df, key_terms)

# %% [markdown]
# 8. Trend Analysis Over Time

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'date' column is in a recognizable date format, if not, convert it
#df['date'] = pd.to_datetime(df['date'])

def trend_analysis(df):
    # Group by Year-Month and count entries
    trend_data = df.groupby(df['date'].dt.to_period('M')).size()
    return trend_data

# Apply the function
monthly_trends = trend_analysis(df)

# Plotting the trend
plt.figure(figsize=(10, 5), dpi=300)
monthly_trends.plot(kind='line', marker='.', title='Monthly Interview Trend', color=color)
plt.xlabel('Month')
plt.ylabel('Number of Interviews')
plt.grid(True)
plt.show()

# %% [markdown]
# Adding Inflation rates

# %%
# !pip install ecbdata
# Out:
# Requirement already satisfied: ecbdata in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (0.0.7)
# Requirement already satisfied: requests in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from ecbdata) (2.31.0)
# Requirement already satisfied: pandas in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from ecbdata) (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from pandas->ecbdata) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from pandas->ecbdata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from pandas->ecbdata) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from pandas->ecbdata) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from requests->ecbdata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from requests->ecbdata) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from requests->ecbdata) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from requests->ecbdata) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/mathieu26/anaconda3/envs/NLP/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->ecbdata) (1.16.0)

# %%
from ecbdata import ecbdata

df2 = ecbdata.get_series('ICP.M.U2.N.000000.4.ANR', 
                        start='2005-01')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df2 is the DataFrame you intend to use
df2['TIME_PERIOD'] = pd.to_datetime(df2['TIME_PERIOD'])  # Convert the 'TIME_PERIOD' column to datetime
df2.set_index('TIME_PERIOD', inplace=True)  # Set 'TIME_PERIOD' as the index of df2

df2['OBS_VALUE'].plot()  # Plot the 'OBS_VALUE' column
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'date' column in first DataFrame is in a recognizable date format, if not, convert it
# df1['date'] = pd.to_datetime(df1['date'])

def trend_analysis(df):
    # Group by Year-Month and count entries
    trend_data = df.groupby(df['date'].dt.to_period('M')).size()
    return trend_data

# Apply the function on the first DataFrame
monthly_trends = trend_analysis(df)  # ensure you use df1 here if that's the intended DataFrame

# Plotting the monthly trend from the first DataFrame
fig, ax = plt.subplots(figsize=(10, 5), dpi=300)
monthly_trends.plot(kind='line', marker='.', title='Monthly Interview Trend', color=color, label='Monthly Interviews', ax=ax)  # color and label adjusted

# Assuming the second DataFrame has already the 'TIME_PERIOD' column converted to datetime
# df2.TIME_PERIOD = pd.to_datetime(df2.TIME_PERIOD)
# df2 = df2.set_index('TIME_PERIOD')

# Overlay the plot from the second DataFrame
df2['OBS_VALUE'].plot(color='green', label='Inflation rate', ax=ax)  # Using a different color and label

# Multiple Annotations
events = {
    'Covid-19 Pandemic': (pd.to_datetime('2020-01-01'), 1.5, pd.to_datetime('2019-03-01'), -0.5),
    'End 1st Lockdown': (pd.to_datetime('2020-07-01'), 10.0, pd.to_datetime('2019-01-01'), 10),
    'End 2st Lockdown': (pd.to_datetime('2020-11-01'), 11.0, pd.to_datetime('2021-01-01'), 10),
    'EU Aid Package': (pd.to_datetime('2021-01-01'), .9, pd.to_datetime('2021-04-01'), -0.4),
    'War in Ukraine': (pd.to_datetime('2022-01-01'), 5.2, pd.to_datetime('2021-03-01'), 7)

}

for label, (important_date, important_value, date_text, value_text) in events.items():
    ax.annotate(label, xy=(important_date, important_value), xytext=(date_text, value_text),
                textcoords='data', 
                arrowprops=dict(arrowstyle='->', color='black', connectionstyle='arc3,rad=0.3'))

# Adding labels and legend
ax.set_xlabel('Date')
ax.set_ylabel('')
ax.grid(True)
ax.legend()

# Show the combined plot
plt.show()

# %% [markdown]
# 9. Keyword Extraction

# %%
"""import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

def extract_keywords(df, top_n=5):
    vectorizer = TfidfVectorizer(stop_words='english')
    tfidf_matrix = vectorizer.fit_transform(df['contents'])
    feature_names = vectorizer.get_feature_names_out()
    
    # Create a list to store keywords for each document
    top_keywords = []

    # Loop through each row in the TF-IDF matrix
    for row in tfidf_matrix:
        # Get the indices of the top n features for this row
        top_n_idx = np.argsort(row.toarray().flatten())[-top_n:]
        # Get the corresponding feature names
        top_features = [feature_names[i] for i in top_n_idx]
        # Add the features as a string separated by commas
        top_keywords.append(", ".join(top_features))

    # Add the keywords as a new column to the DataFrame
    df['top_keywords'] = top_keywords
    return df

# Assume df is your DataFrame and it already has a column 'contents' with text data
# Apply the function
df = extract_keywords(df)

# Display the updated DataFrame
print(df[['contents', 'top_keywords']])
"""
# Out:
# 'import numpy as np\nimport pandas as pd\nfrom sklearn.feature_extraction.text import TfidfVectorizer\n\ndef extract_keywords(df, top_n=5):\n    vectorizer = TfidfVectorizer(stop_words=\'english\')\n    tfidf_matrix = vectorizer.fit_transform(df[\'contents\'])\n    feature_names = vectorizer.get_feature_names_out()\n    \n    # Create a list to store keywords for each document\n    top_keywords = []\n\n    # Loop through each row in the TF-IDF matrix\n    for row in tfidf_matrix:\n        # Get the indices of the top n features for this row\n        top_n_idx = np.argsort(row.toarray().flatten())[-top_n:]\n        # Get the corresponding feature names\n        top_features = [feature_names[i] for i in top_n_idx]\n        # Add the features as a string separated by commas\n        top_keywords.append(", ".join(top_features))\n\n    # Add the keywords as a new column to the DataFrame\n    df[\'top_keywords\'] = top_keywords\n    return df\n\n# Assume df is your DataFrame and it already has a column \'contents\' with text data\n# Apply the function\ndf = extract_keywords(df)\n\n# Display the updated DataFrame\nprint(df[[\'contents\', \'top_keywords\']])\n'

# %% [markdown]
# 10. Language Detection

# %%
from langdetect import detect

def detect_language(df):
    df['language'] = df['contents'].apply(detect)
    return df

# Apply the function
df = detect_language(df)
# Out:
# /var/folders/fx/j6fbl16n4dx92c8z30z6z7fh0000gn/T/ipykernel_53306/2172205828.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['language'] = df['contents'].apply(detect)

# %%
df.head(50)
# Out:
#          date                                              Media  \
# 0  2005-12-23                         Interview with Der Spiegel
# 1  2005-12-19                  Interview with Hospodářské Noviny
# 2  2005-12-19  Interview with Financial Times and Financial T...
# 3  2005-12-15                         Interview with Paris Match
# 4  2005-12-09                           Interview in Il Giornale
# 5  2005-11-24    Interview in Die Welt, La Stampa and Libération
# 6  2005-10-14                            Interview with Izvestia
# 7  2005-09-21  Interview with the Irish Times, Le Figaro, El ...
# 8  2005-08-09                      Interview with Il Sole 24 Ore
# 9  2005-06-27           Interview with La Gaceta de los Negocios
# 10 2005-06-27                       Interview with La Repubblica
# 11 2005-03-31                 Interview with Corriere della Sera
# 12 2005-03-16                      Interview with Il Sole 24 Ore
# 13 2005-02-17                      Interview with Il Sore 24 Ore
# 17 2005-01-20                           Interview with Les Echos
# 18 2006-12-18  Interview with Ta Nea, Der Tagesspiegel and Lu...
# 19 2006-09-15                          Interview with L'Espresso
# 20 2006-06-27  Joint interview with Corriere della Sera, Hels...
# 21 2006-04-11                      Interview with Yediot Ahronot
# 22 2006-03-15  Interview with Der Standard, De Standaard, La ...
# 23 2006-01-26                            Interview with Die Zeit
# 24 2007-10-16                            Interview with Izvestia
# 25 2007-08-11                        Interview with Ouest France
# 27 2007-05-18  Interview with the Financial Times and the Fin...
# 28 2007-05-14            Interview with Nikkei Business Magazine
# 29 2007-04-02  Interview with Dnevnik, Expansión, Irish Indep...
# 30 2007-02-26                               Interview with FOCUS
# 31 2007-02-22                      Interview with Il Sole 24 Ore
# 33 2008-12-23      Interview with Frankfurter Allgemeine Zeitung
# 34 2008-12-15                 Interview with the Financial Times
# 35 2008-11-26                              Interview to Al-Ahram
# 36 2008-11-10                  Interview with Folha de Sao Paulo
# 37 2008-09-23                  Interview with Hospodárske noviny
# 38 2008-07-18  Interview with Le Figaro, Frankfurter Allgemei...
# 40 2008-02-11  Interview with Kyodo News, Nikkei, Nippon Hoso...
# 41 2009-12-10                  Interview with De Tijd and L'Echo
# 42 2009-11-28  Shaping the future of global financial market ...
# 43 2009-11-25             Interview with Het Financieele Dagblad
# 44 2009-11-17                            Interview with Le Monde
# 46 2009-09-27                 Interview with Corriere della Sera
# 48 2009-04-29                 Interview with Süddeutsche Zeitung
# 49 2009-04-09                      Interview with Il Sole 24 Ore
# 50 2009-03-23                 Interview with Wall Street Journal
# 51 2009-02-16                       Interview with China Finance
# 53 2010-11-13                          Interview with Le Progrès
# 54 2010-10-29                             Interview with Politis
# 55 2010-10-17                           Interview with La Stampa
# 56 2010-10-11  Interview with special edition of Frankfurter ...
# 57 2010-09-10                     Interview with Financial Times
# 58 2010-09-03                           Interview with Le Figaro
#
#                          Member  \
# 0           Jean-Claude Trichet
# 1                  Otmar Issing
# 2               Lucas Papademos
# 3           Jean-Claude Trichet
# 4           Lorenzo Bini Smaghi
# 5           Jean-Claude Trichet
# 6           Jean-Claude Trichet
# 7           Jean-Claude Trichet
# 8                  Otmar Issing
# 9   José Manuel González-Páramo
# 10          Lorenzo Bini Smaghi
# 11              Lucas Papademos
# 12          Jean-Claude Trichet
# 13       Tommaso Padoa-Schioppa
# 17          Jean-Claude Trichet
# 18          Jean-Claude Trichet
# 19          Jean-Claude Trichet
# 20          Jean-Claude Trichet
# 21          Jean-Claude Trichet
# 22          Jean-Claude Trichet
# 23          Lorenzo Bini Smaghi
# 24          Jean-Claude Trichet
# 25          Jean-Claude Trichet
# 27          Jean-Claude Trichet
# 28          Jean-Claude Trichet
# 29          Jean-Claude Trichet
# 30          Jean-Claude Trichet
# 31              Lucas Papademos
# 33          Jean-Claude Trichet
# 34          Jean-Claude Trichet
# 35          Jean-Claude Trichet
# 36          Jean-Claude Trichet
# 37          Jean-Claude Trichet
# 38          Jean-Claude Trichet
# 40          Jean-Claude Trichet
# 41          Jean-Claude Trichet
# 42          Jean-Claude Trichet
# 43          Jean-Claude Trichet
# 44          Jean-Claude Trichet
# 46          Jean-Claude Trichet
# 48          Jean-Claude Trichet
# 49          Jean-Claude Trichet
# 50          Jean-Claude Trichet
# 51          Jean-Claude Trichet
# 53          Jean-Claude Trichet
# 54          Jean-Claude Trichet
# 55          Jean-Claude Trichet
# 56          Jean-Claude Trichet
# 57          Jean-Claude Trichet
# 58          Jean-Claude Trichet
#
#                                                  Link            Information  \
# 0   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 1   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 2   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 3   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 4   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 5   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 6   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 7   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 8   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 9   https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 10  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 11  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 12  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 13  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 17  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 18  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 19  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 20  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 21  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 22  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 23  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 24  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 25  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 27  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 28  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 29  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 30  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 31  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 33  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 34  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 35  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 36  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 37  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 38  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 40  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 41  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 42  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 43  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 44  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 46  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 48  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 49  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 50  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 51  https://www.ecb.europa.eu/press/inter/date/200...  Information not found
# 53  https://www.ecb.europa.eu/press/inter/date/201...  Information not found
# 54  https://www.ecb.europa.eu/press/inter/date/201...  Information not found
# 55  https://www.ecb.europa.eu/press/inter/date/201...  Information not found
# 56  https://www.ecb.europa.eu/press/inter/date/201...  Information not found
# 57  https://www.ecb.europa.eu/press/inter/date/201...  Information not found
# 58  https://www.ecb.europa.eu/press/inter/date/201...  Information not found
#
#                                             Questions  \
# 0   SPIEGEL: Monsieur Trichet, any concrete uttera...
# 1   The new EU member states want to adopt the eur...
# 2   Mr Papademos, you have responsibility as ECB V...
# 3   Paris Match. After two uneventful years at the...
# 4   However, Europe’s politicians, with few except...
# 5   Q: You have announced that there is to be a ve...
# 6   “Price stability – we owe that to the people o...
# 7   The euro zone is facing its third oil shock an...
# 8   ECB President Trichet said back in July that t...
# 9   La Gaceta: How does the crisis in Europe stemm...
# 10  Following the “no” to the Constitution in Fran...
# 11  The markets are under the impression that the ...
# 12  [Question] International competition has grown...
# 13  How do you assess developments in the economic...
# 17  With the inauguration of the new Bush administ...
# 18  Can you please describe the current risks of i...
# 19  Mr Trichet, let us begin our examination of Eu...
# 20  1) Mr Prodi, Mrs Merkel and Mr Chirac think th...
# 21  Is there a trade-off between price stability a...
# 22  After the second ECB rate hike, you repeated t...
# 23  Mr Bini Smaghi, for six years the European Cen...
# 24  - May I ask you your opinion about the global ...
# 25  Do the current shocks being felt by the world’...
# 27  FT: It would be interesting to hear your thoug...
# 28  Fifty years have now passed since the signing ...
# 29  One recent survey over the first 5 years since...
# 30  Central bank presidents must take enormous car...
# 31  What type of recovery are we seeing?[end_quest...
# 33  Mr Trichet, ten years ago you were Governor of...
# 34  FT:[end_question] Mr Trichet:[end_question] FT...
# 35  Question:[end_question] Trichet[end_question] ...
# 36  FOLHA[end_question] JEAN-CLAUDE TRICHET[end_qu...
# 37  How will Slovakia’s entry to the euro area cha...
# 38  1. Could you outline how you see the euro econ...
# 40  How do you assess the discussions at this G7 a...
# 41  Is the euro area now definitely out of recessi...
# 42  the quality, consistency and transparency of c...
# 43  Q. How stable is the Stability and Growth Pact...
# 44  The euro area economy grew by 0.4% in the thir...
# 46  Is the improvement in the financial markets in...
# 48  Mr. President, when will the end of the crisis...
# 49  The G20 meeting in London has just finished. A...
# 50  WSJ:[end_question] MR. TRICHET:[end_question] ...
# 51  China Finance:[end_question] Mr Trichet:[end_q...
# 53  Are you satisfied with the conclusions of the ...
# 54  Politis:[end_question] Trichet:[end_question] ...
# 55  Mr President, is the crisis of the euro over?[...
# 56  1. What do you spontaneously associate with Du...
# 57  Financial Times[end_question] Jean-Claude Tric...
# 58  In the second quarter, the level of growth rec...
#
#                                              contents  sentiment  \
# 0   The publication of the translation was authori...   0.137979
# 1   These questions are all closely related to eac...   0.173579
# 2   A comparison of the risks involved when short-...   0.084569
# 3   The publication of the translation was authori...   0.152205
# 4   By Angelo Allegri, our correspondent in Frankf...   0.094762
# 5   The publication of the text was authorised by ...   0.096294
# 6   When the rouble becomes convertible, will Russ...   0.077531
# 7   The publication of the text was authorised by ...   0.158274
# 8   Is the economic slowdown in the first part of ...   0.069662
# 9   English translation of an interview published ...   0.122377
# 10  It is a difficult period, but I think it is an...   0.033590
# 11  Our message has been clear: the current level ...   0.079930
# 12  [Answer] I believe that Europe needs to redoub...   0.138608
# 13  English translation of an interview published ...   0.100416
# 17  English translation of an interview of Jean-Cl...   0.128985
# 18  We have, in the eyes of the Governing Council,...   0.155019
# 19  As early as the second half of 2005 our diagno...   0.108526
# 20  Answer: As you know we have no say and we do n...   0.137486
# 21  The publication of the interview was authorize...   0.162498
# 22  When I reported on the decision of the ECB’s G...   0.162484
# 23  Not really. Compare other countries with the e...   0.103129
# 24  First let me remind you that the ECB as well a...   0.155660
# 25  I said on Thursday 2 August, reporting on the ...   0.218477
# 27  It remains true, of course, that Germany, as w...   0.147638
# 28  The achievements are remarkable, truly histori...   0.133124
# 29  People of Europe are telling us to ensure pric...   0.156151
# 30  We central bankers know that we are watched ve...   0.136749
# 31  According to the latest estimates, growth in t...   0.097475
# 33  At midnight I invited all employees, who had w...   0.117678
# 34  If the situation were to demand now that we ha...   0.106754
# 35  The primary objective of the ECB and the natio...   0.212623
# 36  As regards these turbulences, we have been one...   0.175000
# 37  We are working our monetary policy for the ful...   0.089250
# 38  I always said - on behalf of the Governing Cou...   0.128727
# 40  I think it was a very, very good discussion – ...   0.186980
# 41  Jean-Claude Trichet: The second quarter of thi...   0.103903
# 42  President Trichet, we really appreciate your w...   0.126505
# 43  European banks should reinforce their balance ...   0.118042
# 44  After the second quarter figures, which were s...   0.126557
# 46  “There is a significant improvement in the fun...   0.144024
# 48  It is an on-going phenomenon. That is why we h...   0.112156
# 49  This meeting represents a very, very important...   0.141797
# 50  A number of other factors are also very import...   0.190889
# 51  In recent months we have seen another benefit ...   0.115147
# 53  Let me first of all say how delighted I am to ...   0.079649
# 54  One has to fully understand that in a single c...   0.160700
# 55  I interpret your question as applying more to ...   0.160044
# 56  Was verbinden Sie spontan mit der niederländis...   0.181931
# 57  That would certainly have been considered much...   0.088742
# 58  I will not draw any comparisons between the eu...   0.127808
#
#                                              pos_tags  text_length language
# 0   [(The, DT), (publication, NN), (of, IN), (the,...         9371       en
# 1   [(These, DT), (questions, NNS), (are, VBP), (a...         3209       en
# 2   [(A, DT), (comparison, NN), (of, IN), (the, DT...        16231       en
# 3   [(The, DT), (publication, NN), (of, IN), (the,...         8186       en
# 4   [(By, IN), (Angelo, NNP), (Allegri, NNP), (our...         6765       en
# 5   [(The, DT), (publication, NN), (of, IN), (the,...        11076       en
# 6   [(When, WRB), (the, DT), (rouble, JJ), (become...         7025       en
# 7   [(The, DT), (publication, NN), (of, IN), (the,...        14124       en
# 8   [(Is, VBZ), (the, DT), (economic, JJ), (slowdo...         7212       en
# 9   [(English, JJ), (translation, NN), (of, IN), (...        11720       en
# 10  [(It, PRP), (is, VBZ), (a, DT), (difficult, JJ...         8345       en
# 11  [(Our, PRP$), (message, NN), (has, VBZ), (been...         7745       en
# 12  [([, NN), (Answer, NNP), (], NNP), (I, PRP), (...         7755       en
# 13  [(English, JJ), (translation, NN), (of, IN), (...         6728       en
# 17  [(English, JJ), (translation, NN), (of, IN), (...         7642       en
# 18  [(We, PRP), (have, VBP), (in, IN), (the, DT), ...        17931       en
# 19  [(As, RB), (early, RB), (as, IN), (the, DT), (...         9524       en
# 20  [(Answer, NN), (As, IN), (you, PRP), (know, VB...        17707       en
# 21  [(The, DT), (publication, NN), (of, IN), (the,...         7546       en
# 22  [(When, WRB), (I, PRP), (reported, VBD), (on, ...        16047       en
# 23  [(Not, RB), (really, RB), (Compare, NNP), (oth...         5858       en
# 24  [(First, NNP), (let, VB), (me, PRP), (remind, ...        11962       en
# 25  [(I, PRP), (said, VBD), (on, IN), (Thursday, N...         4232       en
# 27  [(It, PRP), (remains, VBZ), (true, JJ), (of, I...         9262       en
# 28  [(The, DT), (achievements, NNS), (are, VBP), (...         7525       en
# 29  [(People, NNS), (of, IN), (Europe, NNP), (are,...        15873       en
# 30  [(We, PRP), (central, JJ), (bankers, NNS), (kn...         5567       en
# 31  [(According, VBG), (to, TO), (the, DT), (lates...         8929       en
# 33  [(At, IN), (midnight, NN), (I, PRP), (invited,...        11263       en
# 34  [(If, IN), (the, DT), (situation, NN), (were, ...         9030       en
# 35  [(The, DT), (primary, JJ), (objective, NN), (o...         3393       en
# 36  [(As, IN), (regards, NNS), (these, DT), (turbu...          677       en
# 37  [(We, PRP), (are, VBP), (working, VBG), (our, ...         6244       en
# 38  [(I, PRP), (always, RB), (said, VBD), (on, IN)...        20431       en
# 40  [(I, PRP), (think, VBP), (it, PRP), (was, VBD)...        15330       en
# 41  [(Jean-Claude, JJ), (Trichet, NN), (The, DT), ...        16876       en
# 42  [(President, NNP), (Trichet, NNP), (we, PRP), ...         5565       en
# 43  [(European, JJ), (banks, NNS), (should, MD), (...         9671       en
# 44  [(After, IN), (the, DT), (second, JJ), (quarte...        16443       en
# 46  [(“, NN), (There, EX), (is, VBZ), (a, DT), (si...        12310       en
# 48  [(It, PRP), (is, VBZ), (an, DT), (on-going, JJ...         6949       en
# 49  [(This, DT), (meeting, NN), (represents, VBZ),...         7231       en
# 50  [(A, DT), (number, NN), (of, IN), (other, JJ),...         2322       en
# 51  [(In, IN), (recent, JJ), (months, NNS), (we, P...         4267       en
# 53  [(Let, VB), (me, PRP), (first, VB), (of, IN), ...         7806       en
# 54  [(One, CD), (has, VBZ), (to, TO), (fully, RB),...         2039       en
# 55  [(I, PRP), (interpret, VBP), (your, PRP$), (qu...         6538       en
# 56  [(Was, NNP), (verbinden, JJ), (Sie, NNP), (spo...         3616       en
# 57  [(That, DT), (would, MD), (certainly, RB), (ha...         3479       en
# 58  [(I, PRP), (will, MD), (not, RB), (draw, VB), ...         8874       en
